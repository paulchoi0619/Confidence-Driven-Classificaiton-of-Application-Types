# %%
import os
import sys

# %%
import json

with open("client_ip.json", "r") as f:
    client_ip = json.load(f)

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %%
batch_size = 128
features = 40
input_shape = (features,2)

# %%
import matplotlib.pyplot as plt
import numpy as np
WINDOW=40
def lstm_vector(ts1,sizes1,ts2,sizes2,voip=False):
    #determine direction
    if voip:
        src_ts = ts1
        src_sizes = sizes1
        dst_ts = ts2
        dst_sizes = sizes2
    else:
        if ts1[0]<ts2[0]:
            src_ts = ts1
            src_sizes = sizes1
            dst_ts = ts2
            dst_sizes = sizes2
        else:
            src_ts = ts2
            src_sizes = sizes2
            dst_ts = ts1
            dst_sizes = sizes1
    array = []
    j = 0 #src
    k = 0 #dst
    min_val = min(src_ts[0],dst_ts[0])
    length = len(src_ts)+len(dst_ts)
    for i in range(40):
        if j>=len(src_ts) and k>=len(dst_ts):
            break
        if j>=len(src_ts):
            array.append([round(dst_ts[k]-min_val,6),-dst_sizes[k]])
            k+=1
        elif k >= len(dst_ts):
            array.append([round(src_ts[j]-min_val,6),src_sizes[j]]) 
            j+=1
        elif src_ts[j]<=dst_ts[k]:
            array.append([round(src_ts[j]-min_val,6),src_sizes[j]]) 
            j+=1
        else:
            array.append([round(dst_ts[k]-min_val,6),-dst_sizes[k]])
            k+=1
    # for i in range(WINDOW-length):
    #      array.append([0,0])
    array = np.array(array)
    X = array.reshape(-1,2)
    return X

# %%
WINDOW=50
def seq_50(ts1,sizes1,ts2,sizes2):
    #determine direction
    if ts1[0]<ts2[0]:
        src_ts = ts1
        src_sizes = sizes1
        dst_ts = ts2
        dst_sizes = sizes2
    else:
        src_ts = ts2
        src_sizes = sizes2
        dst_ts = ts1
        dst_sizes = sizes1
    array = []
    j = 0 #src
    k = 0 #dst
    min_val = min(src_ts[0],dst_ts[0])
    for i in range(WINDOW):
        if j>=len(src_ts) and k>=len(dst_ts):
            break
        if j>=len(src_ts):
            array.append([round(dst_ts[k]-min_val,6),-dst_sizes[k]])
            k+=1
        elif k >= len(dst_ts):
            array.append([round(src_ts[j]-min_val,6),src_sizes[j]]) 
            j+=1
        elif src_ts[j]<=dst_ts[k]:
            array.append([round(src_ts[j]-min_val,6),src_sizes[j]]) 
            j+=1
        else:
            array.append([round(dst_ts[k]-min_val,6),-dst_sizes[k]])
            k+=1
    for i in range(WINDOW-len(array)):
         array.append([0,0])
    array = np.array(array)
    X = array.reshape(-1,2)
    return X

# %%
def check_strings_in_classname(classname):
    keywords = {
    "web": 0, "video": 1, "social": 2, "email": 3,"voip":4,"chat":5,"gaming":6,"docs":7
    }
    for keyword in keywords:
        if keyword in classname:
            return keywords[keyword] 
    return None

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import TensorBoard, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout,LSTM,BatchNormalization
from keras import backend as K
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from keras.metrics import top_k_categorical_accuracy
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras.backend as K

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall
def f1_score(y_true, y_pred):
    prec = precision(y_true, y_pred)
    rec = recall(y_true, y_pred)
    return 2 * ((prec * rec) / (prec + rec))

# %%
# check_path = os.path.join(checkpoint_dir, MODEL_NAME + 'pseudo_labeled_binary_lstm_acc.weights.h5')
# pipeline.named_steps['model'].load_weights(check_path)

# %%
X_train = []
y_train = []
voip = []
gaming = []
web = []
video = []
social = []
email = []
doc = []
microsoft = []
chat = []
background = []

# %%
path2 = os.path.abspath('..')

# %%
import os
import csv
import tensorflow as tf

folder_path = path2+"/labeled_train"

# %%
import json
def traffic_csv_converter(file_path):
    X_train = []
    y_train = []
    with open(file_path, 'r') as csv_file:
        reader = csv.reader(csv_file)
        filename = os.path.splitext(os.path.basename(file_path))[0]
        flow_val = {}
        class_val = {}
        paired_keys = set()
        for i, row in enumerate(reader):
            class_name = row[0]
            src_ip = row[1]
            src_port = row[2]
            dst_ip = row[3]
            dst_port = row[4]
            length = int(row[7])
            ts = np.array(row[8:8+length], dtype=float)
            sizes = np.array(row[9+length:], dtype=int)
            key = (src_ip, src_port, dst_ip, dst_port)
            reverse_key = (dst_ip, dst_port, src_ip, src_port)
            if reverse_key in flow_val:
                # Found the reverse flow
                opposite_ts, opposite_sizes = flow_val.pop(reverse_key)
                paired_keys.add(key)
                paired_keys.add(reverse_key)
                if len(opposite_ts) + len(ts) < 40: #flow too small
                    continue
                if "voip" in file_path and class_name =="voip":
                    if reverse_key[0] in client_ip:
                        src_ts, src_sizes = opposite_ts, opposite_sizes
                        dst_ts, dst_sizes = ts, sizes
                    else:
                        src_ts, src_sizes = ts, sizes
                        dst_ts, dst_sizes = opposite_ts, opposite_sizes
                    x = lstm_vector(src_ts, src_sizes, dst_ts, dst_sizes,True)
                    v = seq_50(src_ts, src_sizes, dst_ts, dst_sizes)
                else:
                    src_ts, src_sizes = opposite_ts, opposite_sizes
                    dst_ts, dst_sizes = ts, sizes
                    x = lstm_vector(src_ts, src_sizes, dst_ts, dst_sizes)
                    v = seq_50(src_ts, src_sizes, dst_ts, dst_sizes)
                if "voip" in file_path and class_name == "voip":
                    voip.append(v)
                    y_train.append(7)
                    X_train.append(x)
                elif "gaming" in file_path:
                    gaming.append(v)
                    y_train.append(8)
                    X_train.append(x)
                elif class_name == "web":
                    web.append(v)
                    y_train.append(0)
                    X_train.append(x)
                elif class_name == "video":
                    video.append(v)
                    y_train.append(1)
                    X_train.append(x)
                elif class_name == "social":
                    social.append(v)
                    y_train.append(2)
                    X_train.append(x)
                elif class_name == "email":
                    email.append(v)
                    y_train.append(3)
                    X_train.append(x)
                elif class_name == "doc":
                    doc.append(v)
                    y_train.append(4)
                    X_train.append(x)
                elif class_name == "microsoft":
                    microsoft.append(v)
                    y_train.append(5)
                    X_train.append(x)
                elif class_name == "chat":
                    chat.append(v)
                    y_train.append(6)
                    X_train.append(x)
            else:
                # Save forward direction flow
                flow_val[key] = (ts, sizes)
                class_val[key] = class_name
    for key, value in flow_val.items():
        if key[1] == "5353":
            continue
        if len(value[0]) >= 40:
            if "voip" in file_path:
                ts = value[0][:40]
                sizes = value[1][:40]
                if key[0] in client_ip:
                    sizes = value[1][:40]
                else:
                    sizes = -value[1][:40]
                v = np.stack((ts, sizes), axis=1)
                
                if class_val[key] == "voip": #if the flow is unique
                    y_train.append(7)
                    X_train.append(v)
                # else:
                #     y_train.append(9) #if the flow is background
                
                ts = value[0][:50]
                if key[0] in client_ip:
                    sizes = value[1][:50]
                else:
                    sizes = -value[1][:50]
                if len(ts)<50:
                    pad = 50 - len(ts)
                    ts    = np.pad(ts,    (0, pad), mode="constant", constant_values=0)
                    sizes = np.pad(sizes, (0, pad), mode="constant", constant_values=0)
                    
                v = np.stack((ts, sizes), axis=1)
                if class_val[key] == "voip":
                    voip.append(v)
            elif "gaming" in file_path:
                ts = value[0][:40]
                sizes = value[1][:40]
                v = np.stack((ts, sizes), axis=1)
                X_train.append(v)
                y_train.append(8)
                
                ts = value[0][:50]
                sizes = value[1][:50]
                if len(ts)<50:
                    pad = 50 - len(ts)
                    ts    = np.pad(ts,    (0, pad), mode="constant", constant_values=0)
                    sizes = np.pad(sizes, (0, pad), mode="constant", constant_values=0)
                v = np.stack((ts, sizes), axis=1)
                gaming.append(v)
            
            
    return X_train, y_train
def iterate_over_files_in_directory(directory):
    for file_name in os.listdir(directory):
        if file_name.endswith(".csv"):  # You can adjust the file extension if needed
            file_path = os.path.join(directory, file_name)
            yield file_path

# %%
docs_path = folder_path + "/docs"
for file_path in iterate_over_files_in_directory(docs_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
web_path = folder_path + "/web"
for file_path in iterate_over_files_in_directory(web_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
chat_path = folder_path + "/chat"
for file_path in iterate_over_files_in_directory(chat_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
social_path = folder_path + "/social"
for file_path in iterate_over_files_in_directory(social_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
video_path = folder_path + "/video"
for file_path in iterate_over_files_in_directory(video_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
voip_path = folder_path + "/voip"
for file_path in iterate_over_files_in_directory(voip_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
gaming_path = folder_path + "/gaming"
for file_path in iterate_over_files_in_directory(gaming_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
email_path = folder_path + "/email"
for file_path in iterate_over_files_in_directory(email_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)

# %%
import numpy as np

# %%
X_dataset = np.array(X_train)

# %%
X_dataset.shape
# Out:
# (5772, 40, 2)

# %%
y_dataset = np.array(y_train)

# %%
y_dataset.shape
# Out:
# (5772,)

# %%
from collections import Counter
counter = Counter(y_dataset)
counts = [counter.get(i, 0) for i in range(10)]

# %%
max_val = max(counts)

# %%
max_val
# Out:
# 2697

# %%
counts
# Out:
# [2697, 466, 792, 113, 116, 239, 54, 289, 1006, 0]

# %%
def translation(X):
    arrival_times = X
    n,time_steps,features = arrival_times.shape
    for i in range(n):
        threshold_indices = [2,4,6,8,10] 
        max_n =np.random.choice(threshold_indices) 
        n = np.random.randint(1, max_n + 1)  # Shift 1 to `max_n` packets
        t = np.random.randint(0, 40) 
        direction = np.random.choice(['left', 'right'])
        if direction == 'left':
            total_length = arrival_times.shape[1]
            start_index = t-n
            if start_index < 0: 
                valid_portion = arrival_times[i, t - start_index:50]
                assigned_value = valid_portion.shape[0]
                arrival_times[i, 0:assigned_value] = valid_portion
                arrival_times[i, assigned_value+1:] = 0 
            else:
                valid_portion = arrival_times[i, t:(50)]
                assigned_value = arrival_times[i, start_index:50].shape
                zeros = np.zeros((assigned_value[0]-valid_portion.shape[0],2))
                arrival_times[i, start_index:50] = np.concatenate((valid_portion, zeros))  # bounded to the right by 50
            
        else:
            t_val = arrival_times[i, t] 
            last_index = min(t + n, 40) 
            first_val = min(last_index + n, 40)  
            num_to_shift = last_index - t  
            available_space = 40 - first_val 
            if num_to_shift > 0:
                shift_amount = min(num_to_shift, available_space)
                arrival_times[i, first_val:first_val + shift_amount] = arrival_times[i, t:t + shift_amount]
            arrival_times[i, t:last_index] = t_val
    return arrival_times

# %%
voip = np.array(voip)
gaming = np.array(gaming)
web = np.array(web)
video = np.array(video)
social = np.array(social)
email = np.array(email)
doc = np.array(doc)
microsoft = np.array(microsoft)
chat = np.array(chat)
background = np.array(background)

# %%
for i in range(9):
    if i == 0:
        sample = web
    elif i == 1:
        sample = video
    elif i == 2:
        sample = social
    elif i == 3:
        sample = email
    elif i == 4:
        sample = doc
    elif i == 5:
        sample = microsoft
    elif i == 6:
        sample = chat
    elif i == 7:
        sample = voip
    elif i == 8:
        sample = gaming
    indices = tf.range(sample.shape[0])
    value = len(sample)
    
    sampled_indices = np.random.choice(indices, max_val-value, replace=True)
    sampled_X = sample[sampled_indices]
    augmented = translation(sampled_X)
    augmented = augmented[:, :40, :]
    X_dataset = np.vstack((X_dataset,augmented))
    y = np.array([i]*(max_val-value))
    y_dataset = np.concatenate((y_dataset,y))
# Out:
# W0000 00:00:1753804618.357418  801300 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# X_train = np.load('X_train.npy')
# y_train = np.load('y_train.npy')
# X_val = np.load('X_val.npy')
# y_val = np.load('y_val.npy')

# %%
from keras.utils import to_categorical

# %%
y_dataset.shape
# Out:
# (24273,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_dataset, y_dataset, test_size=0.2, random_state=42)

# %%
y_train = to_categorical(y_train, num_classes=9)
y_val = to_categorical(y_val, num_classes=9)

# %%
num_classes = 9

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import TensorBoard, ModelCheckpoint
from keras.models import Sequential
from keras.layers import InputLayer,Conv1D, MaxPooling1D, Flatten, Dense, Dropout,LSTM,BatchNormalization,Bidirectional,LayerNormalization
from keras import backend as K
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from keras.metrics import top_k_categorical_accuracy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers, models
import tensorflow.keras.backend as K
path = os.path.abspath('')


def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def f1_score(y_true, y_pred):
    prec = precision(y_true, y_pred)
    rec = recall(y_true, y_pred)
    return 2 * ((prec * rec) / (prec + rec))

def build_lstm_classifier(input_shape, num_classes, 
                          encoder_units=(128, 64), 
                          projection_dim=64, 
                          dropout_rate=0.1):
    """
    Builds an LSTM-based classifier.

    Args:
      input_shape: tuple, e.g. (timesteps, features)
      num_classes: int, number of target classes
      encoder_units: tuple of two ints, the hidden sizes of the two Bi‑LSTM layers
      projection_dim: int, size of the intermediate dense ('representation') layer
      dropout_rate: float, dropout after the second LSTM

    Returns:
      A tf.keras.Model ready for compilation.
    """
    inputs = layers.Input(shape=input_shape, name="input_sequence")

    # First Bi‑LSTM block
    x = layers.Bidirectional(
        layers.LSTM(encoder_units[0], return_sequences=True),
        name="bi_lstm_1"
    )(inputs)
    x = layers.LayerNormalization(name="ln_1")(x)

    # Second Bi‑LSTM block
    x = layers.Bidirectional(
        layers.LSTM(encoder_units[1], return_sequences=False),
        name="bi_lstm_2"
    )(x)
    x = layers.LayerNormalization(name="ln_2")(x)
    x = layers.Dropout(dropout_rate, name="dropout")(x)

    # Bottleneck / projection
    h = layers.Dense(
        projection_dim, 
        activation="gelu", 
        name="representation"
    )(x)

    # Classification head
    outputs = layers.Dense(
        num_classes, 
        activation="softmax", 
        name="classifier"
    )(h)

    return models.Model(inputs, outputs, name="lstm_classifier")

# Example usage:
timesteps, features = 40, 2       # adjust to your data
num_classes = 9                 # set to your number of classes
model = build_lstm_classifier(
    input_shape=(timesteps, features),
    num_classes=num_classes
)
# Compile the model with custom metrics


# Set up callbacks
checkpoint_dir = os.path.abspath('')+"/tensorboard"
log_dir = os.path.abspath('') + "/log"
MODEL_NAME = "checkpoint"
check_path = os.path.join(checkpoint_dir, MODEL_NAME + 'relevant_lstm_loss.weights.h5')
tensorboard = TensorBoard(log_dir='./Graph', histogram_freq=1, write_graph=True,
                          write_images=True)
checkpointer_loss = ModelCheckpoint(filepath=check_path, verbose=1, save_best_only=True,
                                     save_weights_only=True)
checkpointer_acc = ModelCheckpoint(monitor='val_f1_score', filepath= os.path.join(checkpoint_dir, MODEL_NAME + 'relevant_lstm_acc.weights.h5'), verbose=1,
                                    save_best_only=True, save_weights_only=True,mode='max')
tensorboard.set_model(model)

early_stopping = EarlyStopping(monitor='val_f1_score', patience=50, restore_best_weights=True,mode='max')

# %%
model.compile(loss='categorical_crossentropy',
                                      optimizer='adam',
                                      metrics=['accuracy', f1_score, precision, recall])

# %%
history = model.fit(X_train, y_train, epochs=500, batch_size=batch_size, callbacks=[early_stopping,tensorboard, checkpointer_loss, checkpointer_acc],
         validation_data=(X_val, y_val))
# Out:
# Epoch 1/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.4199 - f1_score: nan - loss: 1.5516 - precision: 0.6833 - recall: 0.2017
# Epoch 1: val_loss improved from inf to 0.59832, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 1: val_f1_score improved from -inf to 0.77657, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 26s 148ms/step - accuracy: 0.4209 - f1_score: nan - loss: 1.5489 - precision: 0.6839 - recall: 0.2030 - val_accuracy: 0.7942 - val_f1_score: 0.7766 - val_loss: 0.5983 - val_precision: 0.8654 - val_recall: 0.7047
# Epoch 2/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7892 - f1_score: 0.7827 - loss: 0.5673 - precision: 0.8416 - recall: 0.7324
# Epoch 2: val_loss improved from 0.59832 to 0.36519, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 2: val_f1_score improved from 0.77657 to 0.86753, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.7894 - f1_score: 0.7829 - loss: 0.5669 - precision: 0.8417 - recall: 0.7326 - val_accuracy: 0.8715 - val_f1_score: 0.8675 - val_loss: 0.3652 - val_precision: 0.8908 - val_recall: 0.8456
# Epoch 3/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8689 - f1_score: 0.8660 - loss: 0.3710 - precision: 0.8901 - recall: 0.8434
# Epoch 3: val_loss improved from 0.36519 to 0.28352, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 3: val_f1_score improved from 0.86753 to 0.89886, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.8690 - f1_score: 0.8661 - loss: 0.3708 - precision: 0.8901 - recall: 0.8435 - val_accuracy: 0.8991 - val_f1_score: 0.8989 - val_loss: 0.2835 - val_precision: 0.9116 - val_recall: 0.8865
# Epoch 4/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9049 - f1_score: 0.9036 - loss: 0.2668 - precision: 0.9185 - recall: 0.8894
# Epoch 4: val_loss improved from 0.28352 to 0.21500, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 4: val_f1_score improved from 0.89886 to 0.92333, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9050 - f1_score: 0.9037 - loss: 0.2667 - precision: 0.9185 - recall: 0.8895 - val_accuracy: 0.9213 - val_f1_score: 0.9233 - val_loss: 0.2150 - val_precision: 0.9327 - val_recall: 0.9142
# Epoch 5/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9231 - f1_score: 0.9227 - loss: 0.2133 - precision: 0.9322 - recall: 0.9135
# Epoch 5: val_loss improved from 0.21500 to 0.20210, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 5: val_f1_score improved from 0.92333 to 0.92634, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9231 - f1_score: 0.9227 - loss: 0.2133 - precision: 0.9322 - recall: 0.9135 - val_accuracy: 0.9250 - val_f1_score: 0.9263 - val_loss: 0.2021 - val_precision: 0.9323 - val_recall: 0.9205
# Epoch 6/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9420 - f1_score: 0.9424 - loss: 0.1624 - precision: 0.9496 - recall: 0.9353
# Epoch 6: val_loss improved from 0.20210 to 0.17573, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 6: val_f1_score improved from 0.92634 to 0.93766, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 142ms/step - accuracy: 0.9420 - f1_score: 0.9424 - loss: 0.1624 - precision: 0.9496 - recall: 0.9353 - val_accuracy: 0.9372 - val_f1_score: 0.9377 - val_loss: 0.1757 - val_precision: 0.9431 - val_recall: 0.9323
# Epoch 7/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9494 - f1_score: 0.9501 - loss: 0.1444 - precision: 0.9550 - recall: 0.9452
# Epoch 7: val_loss did not improve from 0.17573
#
# Epoch 7: val_f1_score did not improve from 0.93766
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9494 - f1_score: 0.9500 - loss: 0.1444 - precision: 0.9550 - recall: 0.9452 - val_accuracy: 0.9298 - val_f1_score: 0.9308 - val_loss: 0.1981 - val_precision: 0.9370 - val_recall: 0.9248
# Epoch 8/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9480 - f1_score: 0.9487 - loss: 0.1418 - precision: 0.9528 - recall: 0.9446
# Epoch 8: val_loss improved from 0.17573 to 0.15012, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 8: val_f1_score improved from 0.93766 to 0.94504, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9480 - f1_score: 0.9487 - loss: 0.1418 - precision: 0.9529 - recall: 0.9447 - val_accuracy: 0.9450 - val_f1_score: 0.9450 - val_loss: 0.1501 - val_precision: 0.9482 - val_recall: 0.9420
# Epoch 9/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9631 - f1_score: 0.9631 - loss: 0.1075 - precision: 0.9656 - recall: 0.9606
# Epoch 9: val_loss did not improve from 0.15012
#
# Epoch 9: val_f1_score improved from 0.94504 to 0.94543, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9631 - f1_score: 0.9631 - loss: 0.1075 - precision: 0.9656 - recall: 0.9606 - val_accuracy: 0.9446 - val_f1_score: 0.9454 - val_loss: 0.1631 - val_precision: 0.9492 - val_recall: 0.9417
# Epoch 10/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9683 - f1_score: 0.9677 - loss: 0.0929 - precision: 0.9703 - recall: 0.9651
# Epoch 10: val_loss did not improve from 0.15012
#
# Epoch 10: val_f1_score improved from 0.94543 to 0.95007, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9683 - f1_score: 0.9677 - loss: 0.0929 - precision: 0.9703 - recall: 0.9651 - val_accuracy: 0.9491 - val_f1_score: 0.9501 - val_loss: 0.1579 - val_precision: 0.9531 - val_recall: 0.9471
# Epoch 11/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9703 - f1_score: 0.9702 - loss: 0.0871 - precision: 0.9724 - recall: 0.9679
# Epoch 11: val_loss improved from 0.15012 to 0.14717, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 11: val_f1_score improved from 0.95007 to 0.95013, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9703 - f1_score: 0.9702 - loss: 0.0871 - precision: 0.9724 - recall: 0.9679 - val_accuracy: 0.9491 - val_f1_score: 0.9501 - val_loss: 0.1472 - val_precision: 0.9530 - val_recall: 0.9473
# Epoch 12/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9724 - f1_score: 0.9724 - loss: 0.0777 - precision: 0.9744 - recall: 0.9705
# Epoch 12: val_loss did not improve from 0.14717
#
# Epoch 12: val_f1_score did not improve from 0.95013
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9724 - f1_score: 0.9724 - loss: 0.0777 - precision: 0.9744 - recall: 0.9705 - val_accuracy: 0.9411 - val_f1_score: 0.9420 - val_loss: 0.1787 - val_precision: 0.9451 - val_recall: 0.9389
# Epoch 13/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9618 - f1_score: 0.9611 - loss: 0.1043 - precision: 0.9634 - recall: 0.9588
# Epoch 13: val_loss improved from 0.14717 to 0.12317, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 13: val_f1_score improved from 0.95013 to 0.96268, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9618 - f1_score: 0.9611 - loss: 0.1041 - precision: 0.9634 - recall: 0.9588 - val_accuracy: 0.9623 - val_f1_score: 0.9627 - val_loss: 0.1232 - val_precision: 0.9643 - val_recall: 0.9611
# Epoch 14/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9819 - f1_score: 0.9822 - loss: 0.0530 - precision: 0.9830 - recall: 0.9814
# Epoch 14: val_loss improved from 0.12317 to 0.11507, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 14: val_f1_score did not improve from 0.96268
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9819 - f1_score: 0.9822 - loss: 0.0530 - precision: 0.9830 - recall: 0.9814 - val_accuracy: 0.9611 - val_f1_score: 0.9615 - val_loss: 0.1151 - val_precision: 0.9636 - val_recall: 0.9595
# Epoch 15/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9817 - f1_score: 0.9819 - loss: 0.0506 - precision: 0.9828 - recall: 0.9810
# Epoch 15: val_loss improved from 0.11507 to 0.10887, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 15: val_f1_score improved from 0.96268 to 0.96663, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9817 - f1_score: 0.9819 - loss: 0.0506 - precision: 0.9828 - recall: 0.9810 - val_accuracy: 0.9660 - val_f1_score: 0.9666 - val_loss: 0.1089 - val_precision: 0.9689 - val_recall: 0.9644
# Epoch 16/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9815 - f1_score: 0.9815 - loss: 0.0522 - precision: 0.9825 - recall: 0.9805
# Epoch 16: val_loss did not improve from 0.10887
#
# Epoch 16: val_f1_score did not improve from 0.96663
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9815 - f1_score: 0.9814 - loss: 0.0523 - precision: 0.9825 - recall: 0.9805 - val_accuracy: 0.9584 - val_f1_score: 0.9593 - val_loss: 0.1353 - val_precision: 0.9612 - val_recall: 0.9574
# Epoch 17/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9800 - f1_score: 0.9799 - loss: 0.0589 - precision: 0.9810 - recall: 0.9788
# Epoch 17: val_loss did not improve from 0.10887
#
# Epoch 17: val_f1_score improved from 0.96663 to 0.96797, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9800 - f1_score: 0.9799 - loss: 0.0589 - precision: 0.9810 - recall: 0.9788 - val_accuracy: 0.9675 - val_f1_score: 0.9680 - val_loss: 0.1164 - val_precision: 0.9689 - val_recall: 0.9671
# Epoch 18/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9856 - f1_score: 0.9857 - loss: 0.0403 - precision: 0.9869 - recall: 0.9845
# Epoch 18: val_loss did not improve from 0.10887
#
# Epoch 18: val_f1_score did not improve from 0.96797
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9856 - f1_score: 0.9857 - loss: 0.0403 - precision: 0.9869 - recall: 0.9845 - val_accuracy: 0.9646 - val_f1_score: 0.9652 - val_loss: 0.1211 - val_precision: 0.9665 - val_recall: 0.9639
# Epoch 19/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9844 - f1_score: 0.9843 - loss: 0.0466 - precision: 0.9850 - recall: 0.9836
# Epoch 19: val_loss did not improve from 0.10887
#
# Epoch 19: val_f1_score did not improve from 0.96797
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9844 - f1_score: 0.9843 - loss: 0.0466 - precision: 0.9850 - recall: 0.9836 - val_accuracy: 0.9607 - val_f1_score: 0.9614 - val_loss: 0.1358 - val_precision: 0.9631 - val_recall: 0.9597
# Epoch 20/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9864 - f1_score: 0.9867 - loss: 0.0403 - precision: 0.9878 - recall: 0.9857
# Epoch 20: val_loss did not improve from 0.10887
#
# Epoch 20: val_f1_score did not improve from 0.96797
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9864 - f1_score: 0.9867 - loss: 0.0403 - precision: 0.9878 - recall: 0.9857 - val_accuracy: 0.9633 - val_f1_score: 0.9636 - val_loss: 0.1238 - val_precision: 0.9655 - val_recall: 0.9617
# Epoch 21/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9869 - f1_score: 0.9873 - loss: 0.0371 - precision: 0.9879 - recall: 0.9866
# Epoch 21: val_loss did not improve from 0.10887
#
# Epoch 21: val_f1_score did not improve from 0.96797
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9868 - f1_score: 0.9873 - loss: 0.0371 - precision: 0.9879 - recall: 0.9866 - val_accuracy: 0.9551 - val_f1_score: 0.9561 - val_loss: 0.1504 - val_precision: 0.9580 - val_recall: 0.9543
# Epoch 22/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9866 - f1_score: 0.9866 - loss: 0.0414 - precision: 0.9871 - recall: 0.9861
# Epoch 22: val_loss improved from 0.10887 to 0.10448, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 22: val_f1_score improved from 0.96797 to 0.97127, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9866 - f1_score: 0.9866 - loss: 0.0414 - precision: 0.9871 - recall: 0.9861 - val_accuracy: 0.9703 - val_f1_score: 0.9713 - val_loss: 0.1045 - val_precision: 0.9726 - val_recall: 0.9700
# Epoch 23/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9858 - f1_score: 0.9861 - loss: 0.0370 - precision: 0.9865 - recall: 0.9857
# Epoch 23: val_loss did not improve from 0.10448
#
# Epoch 23: val_f1_score did not improve from 0.97127
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9858 - f1_score: 0.9861 - loss: 0.0371 - precision: 0.9865 - recall: 0.9857 - val_accuracy: 0.9668 - val_f1_score: 0.9675 - val_loss: 0.1092 - val_precision: 0.9694 - val_recall: 0.9656
# Epoch 24/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9876 - f1_score: 0.9875 - loss: 0.0346 - precision: 0.9879 - recall: 0.9870
# Epoch 24: val_loss did not improve from 0.10448
#
# Epoch 24: val_f1_score did not improve from 0.97127
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9876 - f1_score: 0.9874 - loss: 0.0346 - precision: 0.9879 - recall: 0.9870 - val_accuracy: 0.9664 - val_f1_score: 0.9667 - val_loss: 0.1207 - val_precision: 0.9676 - val_recall: 0.9658
# Epoch 25/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9872 - f1_score: 0.9873 - loss: 0.0379 - precision: 0.9878 - recall: 0.9867
# Epoch 25: val_loss did not improve from 0.10448
#
# Epoch 25: val_f1_score did not improve from 0.97127
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9872 - f1_score: 0.9873 - loss: 0.0379 - precision: 0.9878 - recall: 0.9867 - val_accuracy: 0.9635 - val_f1_score: 0.9643 - val_loss: 0.1164 - val_precision: 0.9655 - val_recall: 0.9631
# Epoch 26/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9880 - f1_score: 0.9880 - loss: 0.0349 - precision: 0.9884 - recall: 0.9877
# Epoch 26: val_loss did not improve from 0.10448
#
# Epoch 26: val_f1_score did not improve from 0.97127
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9880 - f1_score: 0.9880 - loss: 0.0350 - precision: 0.9884 - recall: 0.9877 - val_accuracy: 0.9613 - val_f1_score: 0.9615 - val_loss: 0.1359 - val_precision: 0.9634 - val_recall: 0.9596
# Epoch 27/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9875 - f1_score: 0.9876 - loss: 0.0363 - precision: 0.9883 - recall: 0.9870
# Epoch 27: val_loss did not improve from 0.10448
#
# Epoch 27: val_f1_score did not improve from 0.97127
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9875 - f1_score: 0.9876 - loss: 0.0363 - precision: 0.9883 - recall: 0.9870 - val_accuracy: 0.9679 - val_f1_score: 0.9685 - val_loss: 0.1058 - val_precision: 0.9693 - val_recall: 0.9677
# Epoch 28/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9902 - f1_score: 0.9902 - loss: 0.0283 - precision: 0.9906 - recall: 0.9898
# Epoch 28: val_loss improved from 0.10448 to 0.10012, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 28: val_f1_score improved from 0.97127 to 0.97279, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9902 - f1_score: 0.9902 - loss: 0.0283 - precision: 0.9906 - recall: 0.9898 - val_accuracy: 0.9726 - val_f1_score: 0.9728 - val_loss: 0.1001 - val_precision: 0.9734 - val_recall: 0.9722
# Epoch 29/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9961 - f1_score: 0.9959 - loss: 0.0141 - precision: 0.9962 - recall: 0.9957
# Epoch 29: val_loss did not improve from 0.10012
#
# Epoch 29: val_f1_score did not improve from 0.97279
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9961 - f1_score: 0.9959 - loss: 0.0141 - precision: 0.9961 - recall: 0.9957 - val_accuracy: 0.9681 - val_f1_score: 0.9681 - val_loss: 0.1138 - val_precision: 0.9685 - val_recall: 0.9677
# Epoch 30/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9905 - f1_score: 0.9907 - loss: 0.0269 - precision: 0.9910 - recall: 0.9905
# Epoch 30: val_loss did not improve from 0.10012
#
# Epoch 30: val_f1_score did not improve from 0.97279
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9905 - f1_score: 0.9907 - loss: 0.0269 - precision: 0.9910 - recall: 0.9905 - val_accuracy: 0.9695 - val_f1_score: 0.9699 - val_loss: 0.1136 - val_precision: 0.9707 - val_recall: 0.9691
# Epoch 31/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9912 - f1_score: 0.9913 - loss: 0.0236 - precision: 0.9917 - recall: 0.9909
# Epoch 31: val_loss did not improve from 0.10012
#
# Epoch 31: val_f1_score improved from 0.97279 to 0.97320, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9912 - f1_score: 0.9913 - loss: 0.0236 - precision: 0.9917 - recall: 0.9909 - val_accuracy: 0.9730 - val_f1_score: 0.9732 - val_loss: 0.1075 - val_precision: 0.9738 - val_recall: 0.9726
# Epoch 32/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9954 - f1_score: 0.9954 - loss: 0.0150 - precision: 0.9955 - recall: 0.9952
# Epoch 32: val_loss did not improve from 0.10012
#
# Epoch 32: val_f1_score did not improve from 0.97320
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9954 - f1_score: 0.9954 - loss: 0.0151 - precision: 0.9955 - recall: 0.9952 - val_accuracy: 0.9726 - val_f1_score: 0.9729 - val_loss: 0.1042 - val_precision: 0.9734 - val_recall: 0.9724
# Epoch 33/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9947 - f1_score: 0.9949 - loss: 0.0152 - precision: 0.9950 - recall: 0.9947
# Epoch 33: val_loss did not improve from 0.10012
#
# Epoch 33: val_f1_score did not improve from 0.97320
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9947 - f1_score: 0.9949 - loss: 0.0152 - precision: 0.9950 - recall: 0.9947 - val_accuracy: 0.9732 - val_f1_score: 0.9732 - val_loss: 0.1080 - val_precision: 0.9740 - val_recall: 0.9724
# Epoch 34/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9942 - f1_score: 0.9942 - loss: 0.0197 - precision: 0.9944 - recall: 0.9941
# Epoch 34: val_loss did not improve from 0.10012
#
# Epoch 34: val_f1_score did not improve from 0.97320
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9941 - f1_score: 0.9942 - loss: 0.0198 - precision: 0.9944 - recall: 0.9941 - val_accuracy: 0.9646 - val_f1_score: 0.9649 - val_loss: 0.1247 - val_precision: 0.9655 - val_recall: 0.9643
# Epoch 35/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9845 - f1_score: 0.9846 - loss: 0.0452 - precision: 0.9853 - recall: 0.9839
# Epoch 35: val_loss did not improve from 0.10012
#
# Epoch 35: val_f1_score did not improve from 0.97320
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9844 - f1_score: 0.9846 - loss: 0.0453 - precision: 0.9853 - recall: 0.9839 - val_accuracy: 0.9644 - val_f1_score: 0.9647 - val_loss: 0.1318 - val_precision: 0.9654 - val_recall: 0.9640
# Epoch 36/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9860 - f1_score: 0.9860 - loss: 0.0392 - precision: 0.9865 - recall: 0.9854
# Epoch 36: val_loss did not improve from 0.10012
#
# Epoch 36: val_f1_score did not improve from 0.97320
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9861 - f1_score: 0.9860 - loss: 0.0392 - precision: 0.9865 - recall: 0.9854 - val_accuracy: 0.9697 - val_f1_score: 0.9695 - val_loss: 0.1105 - val_precision: 0.9703 - val_recall: 0.9687
# Epoch 37/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9936 - f1_score: 0.9937 - loss: 0.0199 - precision: 0.9938 - recall: 0.9935
# Epoch 37: val_loss improved from 0.10012 to 0.09300, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 37: val_f1_score improved from 0.97320 to 0.97496, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9936 - f1_score: 0.9937 - loss: 0.0199 - precision: 0.9938 - recall: 0.9935 - val_accuracy: 0.9747 - val_f1_score: 0.9750 - val_loss: 0.0930 - val_precision: 0.9757 - val_recall: 0.9743
# Epoch 38/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9949 - f1_score: 0.9950 - loss: 0.0147 - precision: 0.9951 - recall: 0.9948
# Epoch 38: val_loss did not improve from 0.09300
#
# Epoch 38: val_f1_score did not improve from 0.97496
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9949 - f1_score: 0.9950 - loss: 0.0148 - precision: 0.9951 - recall: 0.9948 - val_accuracy: 0.9697 - val_f1_score: 0.9702 - val_loss: 0.1163 - val_precision: 0.9715 - val_recall: 0.9689
# Epoch 39/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9916 - f1_score: 0.9917 - loss: 0.0244 - precision: 0.9920 - recall: 0.9914
# Epoch 39: val_loss did not improve from 0.09300
#
# Epoch 39: val_f1_score did not improve from 0.97496
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9916 - f1_score: 0.9917 - loss: 0.0244 - precision: 0.9920 - recall: 0.9914 - val_accuracy: 0.9732 - val_f1_score: 0.9732 - val_loss: 0.0958 - val_precision: 0.9736 - val_recall: 0.9728
# Epoch 40/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9935 - f1_score: 0.9935 - loss: 0.0194 - precision: 0.9936 - recall: 0.9933
# Epoch 40: val_loss did not improve from 0.09300
#
# Epoch 40: val_f1_score did not improve from 0.97496
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9935 - f1_score: 0.9934 - loss: 0.0194 - precision: 0.9936 - recall: 0.9933 - val_accuracy: 0.9693 - val_f1_score: 0.9696 - val_loss: 0.1082 - val_precision: 0.9701 - val_recall: 0.9691
# Epoch 41/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9945 - f1_score: 0.9945 - loss: 0.0163 - precision: 0.9947 - recall: 0.9943
# Epoch 41: val_loss did not improve from 0.09300
#
# Epoch 41: val_f1_score did not improve from 0.97496
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9945 - f1_score: 0.9945 - loss: 0.0163 - precision: 0.9947 - recall: 0.9943 - val_accuracy: 0.9718 - val_f1_score: 0.9717 - val_loss: 0.1192 - val_precision: 0.9722 - val_recall: 0.9712
# Epoch 42/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9908 - f1_score: 0.9907 - loss: 0.0264 - precision: 0.9909 - recall: 0.9906
# Epoch 42: val_loss did not improve from 0.09300
#
# Epoch 42: val_f1_score did not improve from 0.97496
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9908 - f1_score: 0.9907 - loss: 0.0265 - precision: 0.9909 - recall: 0.9906 - val_accuracy: 0.9681 - val_f1_score: 0.9685 - val_loss: 0.1313 - val_precision: 0.9694 - val_recall: 0.9676
# Epoch 43/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9912 - f1_score: 0.9910 - loss: 0.0267 - precision: 0.9915 - recall: 0.9904
# Epoch 43: val_loss did not improve from 0.09300
#
# Epoch 43: val_f1_score did not improve from 0.97496
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9912 - f1_score: 0.9910 - loss: 0.0267 - precision: 0.9915 - recall: 0.9904 - val_accuracy: 0.9743 - val_f1_score: 0.9741 - val_loss: 0.1033 - val_precision: 0.9744 - val_recall: 0.9738
# Epoch 44/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9951 - f1_score: 0.9951 - loss: 0.0134 - precision: 0.9952 - recall: 0.9950
# Epoch 44: val_loss did not improve from 0.09300
#
# Epoch 44: val_f1_score did not improve from 0.97496
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9951 - f1_score: 0.9951 - loss: 0.0134 - precision: 0.9952 - recall: 0.9950 - val_accuracy: 0.9699 - val_f1_score: 0.9702 - val_loss: 0.1202 - val_precision: 0.9707 - val_recall: 0.9697
# Epoch 45/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9950 - f1_score: 0.9951 - loss: 0.0166 - precision: 0.9952 - recall: 0.9949
# Epoch 45: val_loss did not improve from 0.09300
#
# Epoch 45: val_f1_score did not improve from 0.97496
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9950 - f1_score: 0.9950 - loss: 0.0166 - precision: 0.9952 - recall: 0.9949 - val_accuracy: 0.9697 - val_f1_score: 0.9700 - val_loss: 0.1146 - val_precision: 0.9705 - val_recall: 0.9696
# Epoch 46/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9915 - f1_score: 0.9916 - loss: 0.0221 - precision: 0.9918 - recall: 0.9915
# Epoch 46: val_loss did not improve from 0.09300
#
# Epoch 46: val_f1_score did not improve from 0.97496
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9915 - f1_score: 0.9916 - loss: 0.0221 - precision: 0.9918 - recall: 0.9915 - val_accuracy: 0.9666 - val_f1_score: 0.9662 - val_loss: 0.1307 - val_precision: 0.9672 - val_recall: 0.9652
# Epoch 47/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9907 - f1_score: 0.9907 - loss: 0.0300 - precision: 0.9912 - recall: 0.9903
# Epoch 47: val_loss did not improve from 0.09300
#
# Epoch 47: val_f1_score did not improve from 0.97496
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9907 - f1_score: 0.9907 - loss: 0.0300 - precision: 0.9912 - recall: 0.9903 - val_accuracy: 0.9708 - val_f1_score: 0.9707 - val_loss: 0.1163 - val_precision: 0.9717 - val_recall: 0.9697
# Epoch 48/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9935 - f1_score: 0.9935 - loss: 0.0174 - precision: 0.9937 - recall: 0.9934
# Epoch 48: val_loss did not improve from 0.09300
#
# Epoch 48: val_f1_score improved from 0.97496 to 0.97580, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9935 - f1_score: 0.9935 - loss: 0.0174 - precision: 0.9937 - recall: 0.9934 - val_accuracy: 0.9757 - val_f1_score: 0.9758 - val_loss: 0.0987 - val_precision: 0.9763 - val_recall: 0.9753
# Epoch 49/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9951 - f1_score: 0.9951 - loss: 0.0147 - precision: 0.9951 - recall: 0.9950
# Epoch 49: val_loss did not improve from 0.09300
#
# Epoch 49: val_f1_score did not improve from 0.97580
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9951 - f1_score: 0.9951 - loss: 0.0147 - precision: 0.9951 - recall: 0.9950 - val_accuracy: 0.9734 - val_f1_score: 0.9739 - val_loss: 0.0992 - val_precision: 0.9743 - val_recall: 0.9735
# Epoch 50/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9958 - f1_score: 0.9956 - loss: 0.0120 - precision: 0.9959 - recall: 0.9954
# Epoch 50: val_loss did not improve from 0.09300
#
# Epoch 50: val_f1_score did not improve from 0.97580
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9958 - f1_score: 0.9956 - loss: 0.0121 - precision: 0.9959 - recall: 0.9954 - val_accuracy: 0.9697 - val_f1_score: 0.9694 - val_loss: 0.1251 - val_precision: 0.9701 - val_recall: 0.9687
# Epoch 51/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9906 - f1_score: 0.9906 - loss: 0.0256 - precision: 0.9907 - recall: 0.9906
# Epoch 51: val_loss did not improve from 0.09300
#
# Epoch 51: val_f1_score did not improve from 0.97580
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9906 - f1_score: 0.9906 - loss: 0.0256 - precision: 0.9907 - recall: 0.9906 - val_accuracy: 0.9734 - val_f1_score: 0.9736 - val_loss: 0.1053 - val_precision: 0.9740 - val_recall: 0.9732
# Epoch 52/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9950 - f1_score: 0.9951 - loss: 0.0132 - precision: 0.9951 - recall: 0.9950
# Epoch 52: val_loss did not improve from 0.09300
#
# Epoch 52: val_f1_score did not improve from 0.97580
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9950 - f1_score: 0.9951 - loss: 0.0132 - precision: 0.9951 - recall: 0.9950 - val_accuracy: 0.9720 - val_f1_score: 0.9722 - val_loss: 0.1117 - val_precision: 0.9726 - val_recall: 0.9718
# Epoch 53/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9938 - f1_score: 0.9938 - loss: 0.0170 - precision: 0.9939 - recall: 0.9938
# Epoch 53: val_loss improved from 0.09300 to 0.08707, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_loss.weights.h5
#
# Epoch 53: val_f1_score improved from 0.97580 to 0.97690, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9938 - f1_score: 0.9938 - loss: 0.0170 - precision: 0.9939 - recall: 0.9938 - val_accuracy: 0.9769 - val_f1_score: 0.9769 - val_loss: 0.0871 - val_precision: 0.9773 - val_recall: 0.9765
# Epoch 54/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9969 - f1_score: 0.9967 - loss: 0.0092 - precision: 0.9969 - recall: 0.9966
# Epoch 54: val_loss did not improve from 0.08707
#
# Epoch 54: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9969 - f1_score: 0.9967 - loss: 0.0092 - precision: 0.9969 - recall: 0.9966 - val_accuracy: 0.9716 - val_f1_score: 0.9723 - val_loss: 0.1118 - val_precision: 0.9734 - val_recall: 0.9712
# Epoch 55/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9950 - f1_score: 0.9950 - loss: 0.0137 - precision: 0.9952 - recall: 0.9949
# Epoch 55: val_loss did not improve from 0.08707
#
# Epoch 55: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9950 - f1_score: 0.9950 - loss: 0.0137 - precision: 0.9952 - recall: 0.9949 - val_accuracy: 0.9747 - val_f1_score: 0.9752 - val_loss: 0.1018 - val_precision: 0.9757 - val_recall: 0.9747
# Epoch 56/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9968 - f1_score: 0.9968 - loss: 0.0072 - precision: 0.9969 - recall: 0.9967
# Epoch 56: val_loss did not improve from 0.08707
#
# Epoch 56: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9968 - f1_score: 0.9968 - loss: 0.0072 - precision: 0.9969 - recall: 0.9967 - val_accuracy: 0.9749 - val_f1_score: 0.9750 - val_loss: 0.1079 - val_precision: 0.9754 - val_recall: 0.9746
# Epoch 57/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9977 - f1_score: 0.9978 - loss: 0.0074 - precision: 0.9981 - recall: 0.9975
# Epoch 57: val_loss did not improve from 0.08707
#
# Epoch 57: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9976 - f1_score: 0.9978 - loss: 0.0074 - precision: 0.9981 - recall: 0.9975 - val_accuracy: 0.9759 - val_f1_score: 0.9757 - val_loss: 0.0993 - val_precision: 0.9763 - val_recall: 0.9751
# Epoch 58/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9919 - f1_score: 0.9921 - loss: 0.0229 - precision: 0.9925 - recall: 0.9917
# Epoch 58: val_loss did not improve from 0.08707
#
# Epoch 58: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9919 - f1_score: 0.9921 - loss: 0.0230 - precision: 0.9925 - recall: 0.9917 - val_accuracy: 0.9720 - val_f1_score: 0.9724 - val_loss: 0.1126 - val_precision: 0.9730 - val_recall: 0.9718
# Epoch 59/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9905 - f1_score: 0.9905 - loss: 0.0294 - precision: 0.9909 - recall: 0.9901
# Epoch 59: val_loss did not improve from 0.08707
#
# Epoch 59: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9905 - f1_score: 0.9905 - loss: 0.0294 - precision: 0.9909 - recall: 0.9901 - val_accuracy: 0.9724 - val_f1_score: 0.9725 - val_loss: 0.1097 - val_precision: 0.9734 - val_recall: 0.9716
# Epoch 60/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9951 - f1_score: 0.9950 - loss: 0.0152 - precision: 0.9951 - recall: 0.9949
# Epoch 60: val_loss did not improve from 0.08707
#
# Epoch 60: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9951 - f1_score: 0.9950 - loss: 0.0152 - precision: 0.9951 - recall: 0.9949 - val_accuracy: 0.9734 - val_f1_score: 0.9734 - val_loss: 0.1110 - val_precision: 0.9736 - val_recall: 0.9732
# Epoch 61/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9953 - f1_score: 0.9952 - loss: 0.0158 - precision: 0.9956 - recall: 0.9948
# Epoch 61: val_loss did not improve from 0.08707
#
# Epoch 61: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9953 - f1_score: 0.9952 - loss: 0.0158 - precision: 0.9956 - recall: 0.9948 - val_accuracy: 0.9753 - val_f1_score: 0.9757 - val_loss: 0.1137 - val_precision: 0.9763 - val_recall: 0.9751
# Epoch 62/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9975 - f1_score: 0.9975 - loss: 0.0088 - precision: 0.9977 - recall: 0.9974
# Epoch 62: val_loss did not improve from 0.08707
#
# Epoch 62: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9974 - f1_score: 0.9975 - loss: 0.0088 - precision: 0.9977 - recall: 0.9974 - val_accuracy: 0.9759 - val_f1_score: 0.9760 - val_loss: 0.1070 - val_precision: 0.9765 - val_recall: 0.9755
# Epoch 63/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9962 - f1_score: 0.9962 - loss: 0.0102 - precision: 0.9962 - recall: 0.9961
# Epoch 63: val_loss did not improve from 0.08707
#
# Epoch 63: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9962 - f1_score: 0.9962 - loss: 0.0102 - precision: 0.9962 - recall: 0.9961 - val_accuracy: 0.9751 - val_f1_score: 0.9753 - val_loss: 0.1028 - val_precision: 0.9757 - val_recall: 0.9749
# Epoch 64/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9964 - f1_score: 0.9965 - loss: 0.0105 - precision: 0.9966 - recall: 0.9964
# Epoch 64: val_loss did not improve from 0.08707
#
# Epoch 64: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9964 - f1_score: 0.9965 - loss: 0.0105 - precision: 0.9966 - recall: 0.9964 - val_accuracy: 0.9751 - val_f1_score: 0.9751 - val_loss: 0.1106 - val_precision: 0.9753 - val_recall: 0.9749
# Epoch 65/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9978 - f1_score: 0.9978 - loss: 0.0074 - precision: 0.9978 - recall: 0.9978
# Epoch 65: val_loss did not improve from 0.08707
#
# Epoch 65: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9978 - f1_score: 0.9978 - loss: 0.0074 - precision: 0.9978 - recall: 0.9978 - val_accuracy: 0.9763 - val_f1_score: 0.9767 - val_loss: 0.1005 - val_precision: 0.9775 - val_recall: 0.9759
# Epoch 66/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9965 - f1_score: 0.9965 - loss: 0.0101 - precision: 0.9966 - recall: 0.9964
# Epoch 70: val_loss did not improve from 0.08707
#
# Epoch 70: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9965 - f1_score: 0.9965 - loss: 0.0101 - precision: 0.9966 - recall: 0.9964 - val_accuracy: 0.9749 - val_f1_score: 0.9748 - val_loss: 0.1000 - val_precision: 0.9755 - val_recall: 0.9740
# Epoch 71/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9956 - f1_score: 0.9957 - loss: 0.0130 - precision: 0.9959 - recall: 0.9955
# Epoch 71: val_loss did not improve from 0.08707
#
# Epoch 71: val_f1_score did not improve from 0.97690
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9956 - f1_score: 0.9957 - loss: 0.0130 - precision: 0.9959 - recall: 0.9955 - val_accuracy: 0.9726 - val_f1_score: 0.9724 - val_loss: 0.1144 - val_precision: 0.9730 - val_recall: 0.9718
# Epoch 72/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9974 - f1_score: 0.9975 - loss: 0.0090 - precision: 0.9977 - recall: 0.9973
# Epoch 72: val_loss did not improve from 0.08707
#
# Epoch 72: val_f1_score improved from 0.97690 to 0.97691, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9974 - f1_score: 0.9975 - loss: 0.0090 - precision: 0.9977 - recall: 0.9973 - val_accuracy: 0.9769 - val_f1_score: 0.9769 - val_loss: 0.0897 - val_precision: 0.9775 - val_recall: 0.9763
# Epoch 73/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9986 - f1_score: 0.9986 - loss: 0.0050 - precision: 0.9986 - recall: 0.9986
# Epoch 73: val_loss did not improve from 0.08707
#
# Epoch 73: val_f1_score improved from 0.97691 to 0.97859, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9986 - f1_score: 0.9986 - loss: 0.0050 - precision: 0.9986 - recall: 0.9986 - val_accuracy: 0.9786 - val_f1_score: 0.9786 - val_loss: 0.0963 - val_precision: 0.9792 - val_recall: 0.9780
# Epoch 74/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9983 - f1_score: 0.9984 - loss: 0.0047 - precision: 0.9984 - recall: 0.9983
# Epoch 74: val_loss did not improve from 0.08707
#
# Epoch 74: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9983 - f1_score: 0.9984 - loss: 0.0047 - precision: 0.9984 - recall: 0.9983 - val_accuracy: 0.9765 - val_f1_score: 0.9769 - val_loss: 0.1028 - val_precision: 0.9779 - val_recall: 0.9759
# Epoch 75/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9979 - f1_score: 0.9979 - loss: 0.0053 - precision: 0.9979 - recall: 0.9978
# Epoch 75: val_loss did not improve from 0.08707
#
# Epoch 75: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9979 - f1_score: 0.9979 - loss: 0.0054 - precision: 0.9979 - recall: 0.9978 - val_accuracy: 0.9753 - val_f1_score: 0.9752 - val_loss: 0.1123 - val_precision: 0.9757 - val_recall: 0.9747
# Epoch 76/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9943 - f1_score: 0.9943 - loss: 0.0178 - precision: 0.9944 - recall: 0.9941
# Epoch 76: val_loss did not improve from 0.08707
#
# Epoch 76: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9943 - f1_score: 0.9943 - loss: 0.0178 - precision: 0.9944 - recall: 0.9941 - val_accuracy: 0.9738 - val_f1_score: 0.9739 - val_loss: 0.1148 - val_precision: 0.9747 - val_recall: 0.9732
# Epoch 77/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9957 - f1_score: 0.9958 - loss: 0.0151 - precision: 0.9959 - recall: 0.9957
# Epoch 77: val_loss did not improve from 0.08707
#
# Epoch 77: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9957 - f1_score: 0.9958 - loss: 0.0151 - precision: 0.9959 - recall: 0.9957 - val_accuracy: 0.9708 - val_f1_score: 0.9711 - val_loss: 0.1258 - val_precision: 0.9719 - val_recall: 0.9703
# Epoch 78/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9945 - f1_score: 0.9947 - loss: 0.0196 - precision: 0.9948 - recall: 0.9945
# Epoch 78: val_loss did not improve from 0.08707
#
# Epoch 78: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9945 - f1_score: 0.9947 - loss: 0.0197 - precision: 0.9948 - recall: 0.9945 - val_accuracy: 0.9740 - val_f1_score: 0.9743 - val_loss: 0.1064 - val_precision: 0.9745 - val_recall: 0.9741
# Epoch 79/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9958 - f1_score: 0.9958 - loss: 0.0133 - precision: 0.9958 - recall: 0.9957
# Epoch 79: val_loss did not improve from 0.08707
#
# Epoch 79: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9958 - f1_score: 0.9958 - loss: 0.0133 - precision: 0.9958 - recall: 0.9957 - val_accuracy: 0.9703 - val_f1_score: 0.9706 - val_loss: 0.1121 - val_precision: 0.9713 - val_recall: 0.9699
# Epoch 80/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9956 - f1_score: 0.9956 - loss: 0.0137 - precision: 0.9956 - recall: 0.9955
# Epoch 80: val_loss did not improve from 0.08707
#
# Epoch 80: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9956 - f1_score: 0.9956 - loss: 0.0137 - precision: 0.9956 - recall: 0.9955 - val_accuracy: 0.9740 - val_f1_score: 0.9742 - val_loss: 0.1156 - val_precision: 0.9745 - val_recall: 0.9738
# Epoch 81/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9964 - f1_score: 0.9964 - loss: 0.0104 - precision: 0.9964 - recall: 0.9964
# Epoch 81: val_loss did not improve from 0.08707
#
# Epoch 81: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9964 - f1_score: 0.9964 - loss: 0.0104 - precision: 0.9964 - recall: 0.9964 - val_accuracy: 0.9738 - val_f1_score: 0.9740 - val_loss: 0.1092 - val_precision: 0.9745 - val_recall: 0.9736
# Epoch 82/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9977 - f1_score: 0.9977 - loss: 0.0070 - precision: 0.9978 - recall: 0.9976
# Epoch 82: val_loss did not improve from 0.08707
#
# Epoch 82: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9977 - f1_score: 0.9977 - loss: 0.0070 - precision: 0.9977 - recall: 0.9976 - val_accuracy: 0.9695 - val_f1_score: 0.9698 - val_loss: 0.1348 - val_precision: 0.9701 - val_recall: 0.9695
# Epoch 83/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9971 - f1_score: 0.9971 - loss: 0.0087 - precision: 0.9971 - recall: 0.9971
# Epoch 83: val_loss did not improve from 0.08707
#
# Epoch 83: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9971 - f1_score: 0.9971 - loss: 0.0087 - precision: 0.9971 - recall: 0.9971 - val_accuracy: 0.9761 - val_f1_score: 0.9762 - val_loss: 0.1018 - val_precision: 0.9767 - val_recall: 0.9757
# Epoch 84/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9970 - f1_score: 0.9970 - loss: 0.0073 - precision: 0.9970 - recall: 0.9970
# Epoch 84: val_loss did not improve from 0.08707
#
# Epoch 84: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9970 - f1_score: 0.9970 - loss: 0.0073 - precision: 0.9970 - recall: 0.9970 - val_accuracy: 0.9644 - val_f1_score: 0.9644 - val_loss: 0.1581 - val_precision: 0.9650 - val_recall: 0.9638
# Epoch 85/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9909 - f1_score: 0.9911 - loss: 0.0249 - precision: 0.9914 - recall: 0.9909
# Epoch 85: val_loss did not improve from 0.08707
#
# Epoch 85: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9909 - f1_score: 0.9911 - loss: 0.0249 - precision: 0.9914 - recall: 0.9909 - val_accuracy: 0.9695 - val_f1_score: 0.9699 - val_loss: 0.1131 - val_precision: 0.9705 - val_recall: 0.9693
# Epoch 86/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9925 - f1_score: 0.9926 - loss: 0.0250 - precision: 0.9927 - recall: 0.9924
# Epoch 86: val_loss did not improve from 0.08707
#
# Epoch 86: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9925 - f1_score: 0.9926 - loss: 0.0250 - precision: 0.9927 - recall: 0.9924 - val_accuracy: 0.9749 - val_f1_score: 0.9750 - val_loss: 0.1057 - val_precision: 0.9753 - val_recall: 0.9747
# Epoch 87/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9945 - f1_score: 0.9945 - loss: 0.0180 - precision: 0.9946 - recall: 0.9945
# Epoch 87: val_loss did not improve from 0.08707
#
# Epoch 87: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.9945 - f1_score: 0.9945 - loss: 0.0180 - precision: 0.9946 - recall: 0.9945 - val_accuracy: 0.9751 - val_f1_score: 0.9752 - val_loss: 0.1012 - val_precision: 0.9760 - val_recall: 0.9744
# Epoch 88/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9986 - f1_score: 0.9986 - loss: 0.0050 - precision: 0.9987 - recall: 0.9986
# Epoch 88: val_loss did not improve from 0.08707
#
# Epoch 88: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9986 - f1_score: 0.9986 - loss: 0.0050 - precision: 0.9986 - recall: 0.9986 - val_accuracy: 0.9759 - val_f1_score: 0.9761 - val_loss: 0.0999 - val_precision: 0.9769 - val_recall: 0.9753
# Epoch 89/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9993 - f1_score: 0.9993 - loss: 0.0028 - precision: 0.9993 - recall: 0.9993
# Epoch 89: val_loss did not improve from 0.08707
#
# Epoch 89: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9993 - f1_score: 0.9993 - loss: 0.0028 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9775 - val_f1_score: 0.9772 - val_loss: 0.1025 - val_precision: 0.9777 - val_recall: 0.9767
# Epoch 90/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9995 - f1_score: 0.9995 - loss: 0.0018 - precision: 0.9995 - recall: 0.9995
# Epoch 90: val_loss did not improve from 0.08707
#
# Epoch 90: val_f1_score did not improve from 0.97859
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9995 - f1_score: 0.9995 - loss: 0.0018 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9771 - val_f1_score: 0.9773 - val_loss: 0.1112 - val_precision: 0.9774 - val_recall: 0.9772
# Epoch 91/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9987 - f1_score: 0.9987 - loss: 0.0029 - precision: 0.9987 - recall: 0.9987
# Epoch 91: val_loss did not improve from 0.08707
#
# Epoch 91: val_f1_score improved from 0.97859 to 0.97911, saving model to /nas/longleaf/home/paulchoi/only_relevant/tensorboard/checkpointrelevant_lstm_acc.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9987 - f1_score: 0.9987 - loss: 0.0029 - precision: 0.9987 - recall: 0.9987 - val_accuracy: 0.9790 - val_f1_score: 0.9791 - val_loss: 0.1023 - val_precision: 0.9794 - val_recall: 0.9788
# Epoch 92/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9987 - f1_score: 0.9987 - loss: 0.0041 - precision: 0.9987 - recall: 0.9987
# Epoch 92: val_loss did not improve from 0.08707
#
# Epoch 92: val_f1_score did not improve from 0.97911
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9987 - f1_score: 0.9987 - loss: 0.0041 - precision: 0.9987 - recall: 0.9987 - val_accuracy: 0.9790 - val_f1_score: 0.9789 - val_loss: 0.0962 - val_precision: 0.9792 - val_recall: 0.9786
# Epoch 93/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9991 - f1_score: 0.9991 - loss: 0.0029 - precision: 0.9991 - recall: 0.9991
# Epoch 93: val_loss did not improve from 0.08707
#
# Epoch 93: val_f1_score did not improve from 0.97911
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9991 - f1_score: 0.9991 - loss: 0.0029 - precision: 0.9991 - recall: 0.9991 - val_accuracy: 0.9769 - val_f1_score: 0.9771 - val_loss: 0.1051 - val_precision: 0.9775 - val_recall: 0.9767
# Epoch 94/500
# ...
# Epoch 138: val_loss did not improve from 0.08707
#
# Epoch 138: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9993 - f1_score: 0.9993 - loss: 0.0024 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9786 - val_f1_score: 0.9785 - val_loss: 0.1107 - val_precision: 0.9790 - val_recall: 0.9780
# Epoch 139/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9981 - f1_score: 0.9981 - loss: 0.0056 - precision: 0.9981 - recall: 0.9981
# Epoch 139: val_loss did not improve from 0.08707
#
# Epoch 139: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9981 - f1_score: 0.9981 - loss: 0.0056 - precision: 0.9981 - recall: 0.9981 - val_accuracy: 0.9683 - val_f1_score: 0.9683 - val_loss: 0.1613 - val_precision: 0.9687 - val_recall: 0.9679
# Epoch 140/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9947 - f1_score: 0.9948 - loss: 0.0167 - precision: 0.9949 - recall: 0.9947
# Epoch 140: val_loss did not improve from 0.08707
#
# Epoch 140: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9947 - f1_score: 0.9948 - loss: 0.0167 - precision: 0.9949 - recall: 0.9947 - val_accuracy: 0.9673 - val_f1_score: 0.9672 - val_loss: 0.1615 - val_precision: 0.9673 - val_recall: 0.9671
# Epoch 141/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9960 - f1_score: 0.9960 - loss: 0.0116 - precision: 0.9960 - recall: 0.9960
# Epoch 141: val_loss did not improve from 0.08707
#
# Epoch 141: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.9960 - f1_score: 0.9960 - loss: 0.0116 - precision: 0.9960 - recall: 0.9960 - val_accuracy: 0.9775 - val_f1_score: 0.9778 - val_loss: 0.1102 - val_precision: 0.9780 - val_recall: 0.9776
# Epoch 142/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9962 - f1_score: 0.9963 - loss: 0.0104 - precision: 0.9964 - recall: 0.9962
# Epoch 142: val_loss did not improve from 0.08707
#
# Epoch 142: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9962 - f1_score: 0.9963 - loss: 0.0104 - precision: 0.9964 - recall: 0.9962 - val_accuracy: 0.9784 - val_f1_score: 0.9785 - val_loss: 0.1058 - val_precision: 0.9788 - val_recall: 0.9782
# Epoch 143/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9979 - f1_score: 0.9979 - loss: 0.0055 - precision: 0.9979 - recall: 0.9979
# Epoch 143: val_loss did not improve from 0.08707
#
# Epoch 143: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.9979 - f1_score: 0.9979 - loss: 0.0055 - precision: 0.9979 - recall: 0.9979 - val_accuracy: 0.9761 - val_f1_score: 0.9760 - val_loss: 0.1247 - val_precision: 0.9765 - val_recall: 0.9755
# Epoch 144/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9964 - f1_score: 0.9964 - loss: 0.0105 - precision: 0.9965 - recall: 0.9964
# Epoch 144: val_loss did not improve from 0.08707
#
# Epoch 144: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9964 - f1_score: 0.9964 - loss: 0.0105 - precision: 0.9965 - recall: 0.9964 - val_accuracy: 0.9732 - val_f1_score: 0.9735 - val_loss: 0.1375 - val_precision: 0.9740 - val_recall: 0.9730
# Epoch 145/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9965 - f1_score: 0.9965 - loss: 0.0115 - precision: 0.9966 - recall: 0.9965
# Epoch 145: val_loss did not improve from 0.08707
#
# Epoch 145: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9965 - f1_score: 0.9965 - loss: 0.0115 - precision: 0.9966 - recall: 0.9965 - val_accuracy: 0.9771 - val_f1_score: 0.9773 - val_loss: 0.1214 - val_precision: 0.9776 - val_recall: 0.9770
# Epoch 146/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9997 - f1_score: 0.9997 - loss: 0.0014 - precision: 0.9998 - recall: 0.9997
# Epoch 146: val_loss did not improve from 0.08707
#
# Epoch 146: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9997 - f1_score: 0.9997 - loss: 0.0014 - precision: 0.9998 - recall: 0.9997 - val_accuracy: 0.9784 - val_f1_score: 0.9785 - val_loss: 0.1128 - val_precision: 0.9786 - val_recall: 0.9784
# Epoch 147/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9997 - f1_score: 0.9997 - loss: 0.0011 - precision: 0.9997 - recall: 0.9996
# Epoch 147: val_loss did not improve from 0.08707
#
# Epoch 147: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9997 - f1_score: 0.9997 - loss: 0.0011 - precision: 0.9997 - recall: 0.9996 - val_accuracy: 0.9775 - val_f1_score: 0.9776 - val_loss: 0.1187 - val_precision: 0.9780 - val_recall: 0.9772
# Epoch 148/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9998 - f1_score: 0.9998 - loss: 0.0013 - precision: 0.9998 - recall: 0.9998
# Epoch 148: val_loss did not improve from 0.08707
#
# Epoch 148: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9998 - f1_score: 0.9998 - loss: 0.0013 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.9790 - val_f1_score: 0.9791 - val_loss: 0.1131 - val_precision: 0.9794 - val_recall: 0.9788
# Epoch 149/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9998 - f1_score: 0.9998 - loss: 0.0011 - precision: 0.9998 - recall: 0.9998
# Epoch 149: val_loss did not improve from 0.08707
#
# Epoch 149: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9998 - f1_score: 0.9998 - loss: 0.0011 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.9773 - val_f1_score: 0.9777 - val_loss: 0.1176 - val_precision: 0.9782 - val_recall: 0.9771
# Epoch 150/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9996 - f1_score: 0.9996 - loss: 9.6766e-04 - precision: 0.9996 - recall: 0.9996
# Epoch 150: val_loss did not improve from 0.08707
#
# Epoch 150: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9996 - f1_score: 0.9996 - loss: 9.6815e-04 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9773 - val_f1_score: 0.9777 - val_loss: 0.1221 - val_precision: 0.9782 - val_recall: 0.9772
# Epoch 151/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9995 - f1_score: 0.9995 - loss: 0.0020 - precision: 0.9995 - recall: 0.9995
# Epoch 151: val_loss did not improve from 0.08707
#
# Epoch 151: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9995 - f1_score: 0.9995 - loss: 0.0020 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9765 - val_f1_score: 0.9764 - val_loss: 0.1339 - val_precision: 0.9767 - val_recall: 0.9761
# Epoch 152/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9942 - f1_score: 0.9942 - loss: 0.0166 - precision: 0.9943 - recall: 0.9941
# Epoch 152: val_loss did not improve from 0.08707
#
# Epoch 152: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9942 - f1_score: 0.9942 - loss: 0.0167 - precision: 0.9943 - recall: 0.9940 - val_accuracy: 0.9687 - val_f1_score: 0.9691 - val_loss: 0.1382 - val_precision: 0.9697 - val_recall: 0.9685
# Epoch 153/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9942 - f1_score: 0.9942 - loss: 0.0214 - precision: 0.9943 - recall: 0.9941
# Epoch 153: val_loss did not improve from 0.08707
#
# Epoch 153: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9942 - f1_score: 0.9942 - loss: 0.0215 - precision: 0.9943 - recall: 0.9941 - val_accuracy: 0.9644 - val_f1_score: 0.9644 - val_loss: 0.1613 - val_precision: 0.9649 - val_recall: 0.9640
# Epoch 154/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9917 - f1_score: 0.9919 - loss: 0.0261 - precision: 0.9922 - recall: 0.9917
# Epoch 154: val_loss did not improve from 0.08707
#
# Epoch 154: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9917 - f1_score: 0.9920 - loss: 0.0261 - precision: 0.9922 - recall: 0.9917 - val_accuracy: 0.9730 - val_f1_score: 0.9731 - val_loss: 0.1261 - val_precision: 0.9736 - val_recall: 0.9726
# Epoch 155/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9966 - f1_score: 0.9965 - loss: 0.0100 - precision: 0.9966 - recall: 0.9965
# Epoch 155: val_loss did not improve from 0.08707
#
# Epoch 155: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 142ms/step - accuracy: 0.9966 - f1_score: 0.9965 - loss: 0.0100 - precision: 0.9966 - recall: 0.9965 - val_accuracy: 0.9740 - val_f1_score: 0.9746 - val_loss: 0.1200 - val_precision: 0.9751 - val_recall: 0.9741
# Epoch 156/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9959 - f1_score: 0.9958 - loss: 0.0115 - precision: 0.9959 - recall: 0.9957
# Epoch 156: val_loss did not improve from 0.08707
#
# Epoch 156: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9959 - f1_score: 0.9958 - loss: 0.0114 - precision: 0.9959 - recall: 0.9957 - val_accuracy: 0.9763 - val_f1_score: 0.9766 - val_loss: 0.1102 - val_precision: 0.9771 - val_recall: 0.9761
# Epoch 157/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9978 - f1_score: 0.9978 - loss: 0.0047 - precision: 0.9978 - recall: 0.9978
# Epoch 157: val_loss did not improve from 0.08707
#
# Epoch 157: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9978 - f1_score: 0.9978 - loss: 0.0047 - precision: 0.9978 - recall: 0.9978 - val_accuracy: 0.9778 - val_f1_score: 0.9777 - val_loss: 0.1109 - val_precision: 0.9777 - val_recall: 0.9777
# Epoch 158/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9993 - f1_score: 0.9993 - loss: 0.0020 - precision: 0.9993 - recall: 0.9993
# Epoch 158: val_loss did not improve from 0.08707
#
# Epoch 158: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 142ms/step - accuracy: 0.9993 - f1_score: 0.9993 - loss: 0.0020 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9786 - val_f1_score: 0.9788 - val_loss: 0.1023 - val_precision: 0.9796 - val_recall: 0.9780
# Epoch 159/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9997 - f1_score: 0.9997 - loss: 0.0016 - precision: 0.9997 - recall: 0.9997
# Epoch 159: val_loss did not improve from 0.08707
#
# Epoch 159: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 142ms/step - accuracy: 0.9997 - f1_score: 0.9997 - loss: 0.0016 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9755 - val_f1_score: 0.9757 - val_loss: 0.1127 - val_precision: 0.9759 - val_recall: 0.9755
# Epoch 160/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9996 - f1_score: 0.9996 - loss: 9.9531e-04 - precision: 0.9996 - recall: 0.9996
# Epoch 160: val_loss did not improve from 0.08707
#
# Epoch 160: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 142ms/step - accuracy: 0.9996 - f1_score: 0.9996 - loss: 9.9439e-04 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9782 - val_f1_score: 0.9785 - val_loss: 0.1096 - val_precision: 0.9788 - val_recall: 0.9782
# Epoch 161/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9998 - f1_score: 0.9998 - loss: 6.9573e-04 - precision: 0.9998 - recall: 0.9998
# Epoch 161: val_loss did not improve from 0.08707
#
# Epoch 161: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 142ms/step - accuracy: 0.9998 - f1_score: 0.9998 - loss: 6.9638e-04 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.9792 - val_f1_score: 0.9791 - val_loss: 0.1156 - val_precision: 0.9792 - val_recall: 0.9790
# Epoch 162/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9999 - f1_score: 0.9999 - loss: 5.4725e-04 - precision: 0.9999 - recall: 0.9999
# Epoch 162: val_loss did not improve from 0.08707
#
# Epoch 162: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9999 - f1_score: 0.9999 - loss: 5.4761e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9792 - val_f1_score: 0.9794 - val_loss: 0.1076 - val_precision: 0.9798 - val_recall: 0.9790
# Epoch 163/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9999 - f1_score: 0.9999 - loss: 5.1556e-04 - precision: 0.9999 - recall: 0.9999
# Epoch 163: val_loss did not improve from 0.08707
#
# Epoch 163: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9999 - f1_score: 0.9999 - loss: 5.1754e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9775 - val_f1_score: 0.9777 - val_loss: 0.1073 - val_precision: 0.9780 - val_recall: 0.9775
# Epoch 164/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9992 - f1_score: 0.9992 - loss: 0.0016 - precision: 0.9992 - recall: 0.9992
# Epoch 164: val_loss did not improve from 0.08707
#
# Epoch 164: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9992 - f1_score: 0.9992 - loss: 0.0016 - precision: 0.9992 - recall: 0.9992 - val_accuracy: 0.9782 - val_f1_score: 0.9782 - val_loss: 0.1086 - val_precision: 0.9786 - val_recall: 0.9778
# Epoch 165/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9998 - f1_score: 0.9998 - loss: 9.9415e-04 - precision: 0.9998 - recall: 0.9998
# Epoch 165: val_loss did not improve from 0.08707
#
# Epoch 165: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9998 - f1_score: 0.9998 - loss: 0.0010 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.9792 - val_f1_score: 0.9794 - val_loss: 0.1158 - val_precision: 0.9800 - val_recall: 0.9788
# Epoch 166/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9990 - f1_score: 0.9990 - loss: 0.0024 - precision: 0.9990 - recall: 0.9990
# Epoch 166: val_loss did not improve from 0.08707
#
# Epoch 166: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 142ms/step - accuracy: 0.9990 - f1_score: 0.9990 - loss: 0.0024 - precision: 0.9990 - recall: 0.9990 - val_accuracy: 0.9769 - val_f1_score: 0.9771 - val_loss: 0.1247 - val_precision: 0.9773 - val_recall: 0.9769
# Epoch 167/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9895 - f1_score: 0.9895 - loss: 0.0319 - precision: 0.9897 - recall: 0.9893
# Epoch 167: val_loss did not improve from 0.08707
#
# Epoch 167: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 142ms/step - accuracy: 0.9894 - f1_score: 0.9895 - loss: 0.0320 - precision: 0.9897 - recall: 0.9892 - val_accuracy: 0.9590 - val_f1_score: 0.9589 - val_loss: 0.2005 - val_precision: 0.9598 - val_recall: 0.9580
# Epoch 168/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9889 - f1_score: 0.9888 - loss: 0.0366 - precision: 0.9891 - recall: 0.9885
# Epoch 168: val_loss did not improve from 0.08707
#
# Epoch 168: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9889 - f1_score: 0.9888 - loss: 0.0366 - precision: 0.9891 - recall: 0.9885 - val_accuracy: 0.9751 - val_f1_score: 0.9753 - val_loss: 0.1136 - val_precision: 0.9759 - val_recall: 0.9747
# Epoch 169/500
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9971 - f1_score: 0.9970 - loss: 0.0080 - precision: 0.9971 - recall: 0.9968
# Epoch 169: val_loss did not improve from 0.08707
#
# Epoch 169: val_f1_score did not improve from 0.97981
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.9971 - f1_score: 0.9970 - loss: 0.0080 - precision: 0.9971 - recall: 0.9968 - val_accuracy: 0.9757 - val_f1_score: 0.9759 - val_loss: 0.0965 - val_precision: 0.9761 - val_recall: 0.9757
# Epoch 170/500
#  27/152 ━━━━━━━━━━━━━━━━━━━━ 16s 131ms/step - accuracy: 0.9971 - f1_score: 0.9971 - loss: 0.0063 - precision: 0.9971 - recall: 0.9971
# KeyboardInterrupt

# %%
from tensorflow.keras import Input
check_path = os.path.join(checkpoint_dir, MODEL_NAME + 'relevant_lstm_acc.weights.h5')
input_shape = (50, 2)
model.load_weights(check_path)

# %%
X_test = []
y_test = []

# %%
import csv
def test_traffic_csv_converter(file_path):
    X_train = []
    y_train = []
    with open(file_path, 'r') as csv_file:
        reader = csv.reader(csv_file)
        filename = os.path.splitext(os.path.basename(file_path))[0]
        flow_val = {}
        class_val = {}
        paired_keys = set()
        for i, row in enumerate(reader):
            class_name = row[0]
            src_ip = row[1]
            src_port = row[2]
            dst_ip = row[3]
            dst_port = row[4]
            length = int(row[7])
            ts = np.array(row[8:8+length], dtype=float)
            sizes = np.array(row[9+length:], dtype=int)
            key = (src_ip, src_port, dst_ip, dst_port)
            reverse_key = (dst_ip, dst_port, src_ip, src_port)
            if reverse_key in flow_val:
                # Found the reverse flow
                opposite_ts, opposite_sizes = flow_val.pop(reverse_key)
                paired_keys.add(key)
                paired_keys.add(reverse_key)
                if len(opposite_ts) + len(ts) < 40: #flow too small
                    continue
                if "voip" in file_path and class_name =="voip":
                    if reverse_key[0] in client_ip:
                        src_ts, src_sizes = opposite_ts, opposite_sizes
                        dst_ts, dst_sizes = ts, sizes
                    else:
                        src_ts, src_sizes = ts, sizes
                        dst_ts, dst_sizes = opposite_ts, opposite_sizes
                    x = lstm_vector(src_ts, src_sizes, dst_ts, dst_sizes,True)
                    v = seq_50(src_ts, src_sizes, dst_ts, dst_sizes)
                else:
                    src_ts, src_sizes = opposite_ts, opposite_sizes
                    dst_ts, dst_sizes = ts, sizes
                    x = lstm_vector(src_ts, src_sizes, dst_ts, dst_sizes)
                    v = seq_50(src_ts, src_sizes, dst_ts, dst_sizes)
                if "voip" in file_path and class_name == "voip":
                    # voip.append(v)
                    y_train.append(7)
                    X_train.append(x)
                elif "gaming" in file_path:
                    # gaming.append(v)
                    y_train.append(8)
                    X_train.append(x)
                elif class_name == "web":
                    # web.append(v)
                    y_train.append(0)
                    X_train.append(x)
                elif class_name == "video":
                    # video.append(v)
                    y_train.append(1)
                    X_train.append(x)
                elif class_name == "social":
                    # social.append(v)
                    y_train.append(2)
                    X_train.append(x)
                elif class_name == "email":
                    # email.append(v)
                    y_train.append(3)
                    X_train.append(x)
                elif class_name == "doc":
                    # doc.append(v)
                    y_train.append(4)
                    X_train.append(x)
                elif class_name == "microsoft":
                    # microsoft.append(v)
                    y_train.append(5)
                    X_train.append(x)
                elif class_name == "chat":
                    # chat.append(v)
                    y_train.append(6)
                    X_train.append(x)
            else:
                # Save forward direction flow
                flow_val[key] = (ts, sizes)
                class_val[key] = class_name
    for key, value in flow_val.items():
        if key[1] == "5353":
            continue
        if len(value[0]) >= 40:
            if "voip" in file_path:
                ts = value[0][:40]
                sizes = value[1][:40]
                if key[0] in client_ip:
                    sizes = value[1][:40]
                else:
                    sizes = -value[1][:40]
                v = np.stack((ts, sizes), axis=1)
                
                if class_val[key] == "voip": #if the flow is unique
                    y_train.append(7)
                    X_train.append(v)
                # else:
                #     y_train.append(9) #if the flow is background
                
                ts = value[0][:50]
                if key[0] in client_ip:
                    sizes = value[1][:50]
                else:
                    sizes = -value[1][:50]
                if len(ts)<50:
                    pad = 50 - len(ts)
                    ts    = np.pad(ts,    (0, pad), mode="constant", constant_values=0)
                    sizes = np.pad(sizes, (0, pad), mode="constant", constant_values=0)
                    
                v = np.stack((ts, sizes), axis=1)
            elif "gaming" in file_path:
                ts = value[0][:40]
                sizes = value[1][:40]
                v = np.stack((ts, sizes), axis=1)
                X_train.append(v)
                y_train.append(8)
                
                ts = value[0][:50]
                sizes = value[1][:50]
                if len(ts)<50:
                    pad = 50 - len(ts)
                    ts    = np.pad(ts,    (0, pad), mode="constant", constant_values=0)
                    sizes = np.pad(sizes, (0, pad), mode="constant", constant_values=0)
                v = np.stack((ts, sizes), axis=1)
                # gaming.append(v)
            
            
    return X_train, y_train

# %%
folder_path = os.path.abspath('..')+"/labeled_test"
docs_path = folder_path + "/docs"
for file_path in iterate_over_files_in_directory(docs_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
web_path = folder_path + "/web"
for file_path in iterate_over_files_in_directory(web_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
chat_path = folder_path + "/chat"
for file_path in iterate_over_files_in_directory(chat_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
social_path = folder_path + "/social"
for file_path in iterate_over_files_in_directory(social_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
video_path = folder_path + "/video"
for file_path in iterate_over_files_in_directory(video_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
voip_path = folder_path + "/voip"
for file_path in iterate_over_files_in_directory(voip_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
gaming_path = folder_path + "/gaming"
for file_path in iterate_over_files_in_directory(gaming_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
email_path = folder_path + "/email"
for file_path in iterate_over_files_in_directory(email_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)

# %%
X_test = np.array(X_test)

# %%
y_test=np.array(y_test)
y_test.shape
# Out:
# (2158,)

# %%
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step

# %%
y_test=np.array(y_test)
y_test_categorical = y_test

# %%
def weighted_accuracy(y_true, y_pred, flow_sizes):
    total_flow_size = sum(flow_sizes)
    weighted_acc = 0
    for i, flow_size in enumerate(flow_sizes):
        if y_true[i] == y_pred[i]:
            prediction = 1
        else:
            prediction = 0
        weighted_acc += flow_size * prediction
    weighted_acc /= total_flow_size
    
    return weighted_acc

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
# weighted_accuracy = round(weighted_accuracy(y_test_categorical, y_pred, flow_sizes), 2)
macro_f1 = round(f1_score(y_test_categorical, y_pred, average='macro'), 2)
accuracy = round(accuracy_score(y_test_categorical, y_pred), 2)
average_f1 = round(f1_score(y_test_categorical, y_pred, average='weighted'), 2)
# precision = precision_score(y_test_categorical, y_pred, average=None)
# recall = recall_score(y_test_categorical, y_pred, average=None)
# f1 = f1_score(y_test_categorical, y_pred, average=None)
conf_matrix = confusion_matrix(y_test_categorical, y_pred)

# Print or use the evaluation metrics as needed
# print(f'Weighted Average Accuracy: {weighted_accuracy}')
print(f'Macro Average F1 Score: {macro_f1}')
print(f'Accuracy: {accuracy}')
print(f'Weighted Average F1 Score: {average_f1}')
# print(f'Precision: {precision}')
# print(f'Recall: {recall}')
# print(f'F1 Score: {f1}')
# print(f'Confusion Matrix:\n{conf_matrix}')
# Out:
# Macro Average F1 Score: 0.92
# Accuracy: 0.95
# Weighted Average F1 Score: 0.95

# %%
import seaborn as sns
import matplotlib.pyplot as plt

conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

class_names = ["Web","Video","Social","Email","Doc","Microsoft","Chat","VoIP","Gaming"]
# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names,annot_kws={"size": 14})
# ax = sns.heatmap(conf_matrix_percentage, annot=True, fmt='.2f', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
# for t in ax.texts: t.set_text(t.get_text() + " %")
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('True', fontsize=14)
plt.title('Confusion Matrix')
plt.savefig('40 >40 confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

class_names = ["Web","Video","Social","Email","Doc","Microsoft","Chat","VoIP","Gaming"]

# Plot confusion matrix
plt.figure(figsize=(8, 6))
annot_kws = {"size": 11}
# sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
ax = sns.heatmap(conf_matrix_percentage, annot=True, fmt='.1f', cmap='Blues', xticklabels=class_names, yticklabels=class_names,annot_kws=annot_kws)
for t in ax.texts: t.set_text(t.get_text() + " %")
plt.xlabel('Predicted', fontsize=14)  
plt.ylabel('True', fontsize=14)
plt.title('Confusion Matrix')
plt.savefig('40 >40 confusion_matrixpercent.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# mask for misclassified samples
mask = (y_pred != y_test)

# pick out the probability that the model assigned to its (wrong) prediction
mis_probs = y_pred_prob[mask, y_pred[mask]]

# plot a histogram of those confidences
plt.figure()
plt.hist(mis_probs, bins=20)
plt.xlabel('Softmax probability of predicted class')
plt.ylabel('Number of misclassified samples')
plt.title('Confidence distribution for misclassified samples')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) Select only the misclassified samples
mask = (y_pred != y_test)

# 2) Grab the softmax score assigned to the (wrong) predicted class
mis_probs = y_pred_prob[mask, y_pred[mask]]

# 3) Sort and build the CDF
sorted_probs = np.sort(mis_probs)
cdf = np.arange(1, len(sorted_probs) + 1) / len(sorted_probs)

# 4) Plot
plt.figure()
plt.plot(sorted_probs, cdf)
plt.xlabel('Softmax probability of predicted class')
plt.ylabel('Cumulative proportion')
plt.title('CDF of Softmax Probabilities for Misclassified Samples')
plt.show()

# %%
y_pred = np.argmax(y_pred_prob, axis=1)
confidences = np.max(y_pred_prob, axis=1) 
mask_high_conf = confidences >= 0.9
y_pred_prob_filtered = y_pred_prob[mask_high_conf]
y_pred_filtered = y_pred[mask_high_conf]

# %%
y_test_filtered = y_test[mask_high_conf]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
# weighted_accuracy = round(weighted_accuracy(y_test_categorical, y_pred, flow_sizes), 2)
macro_f1 = round(f1_score(y_test_filtered, y_pred_filtered, average='macro'), 2)
accuracy = round(accuracy_score(y_test_filtered, y_pred_filtered), 2)
average_f1 = round(f1_score(y_test_filtered, y_pred_filtered, average='weighted'), 2)
# precision = precision_score(y_test_categorical, y_pred, average=None)
# recall = recall_score(y_test_categorical, y_pred, average=None)
# f1 = f1_score(y_test_categorical, y_pred, average=None)
conf_matrix = confusion_matrix(y_test_filtered, y_pred_filtered)

# Print or use the evaluation metrics as needed
# print(f'Weighted Average Accuracy: {weighted_accuracy}')
print(f'Macro Average F1 Score: {macro_f1}')
print(f'Accuracy: {accuracy}')
print(f'Weighted Average F1 Score: {average_f1}')
# print(f'Precision: {precision}')
# print(f'Recall: {recall}')
# print(f'F1 Score: {f1}')
# print(f'Confusion Matrix:\n{conf_matrix}')
# Out:
# Macro Average F1 Score: 0.87
# Accuracy: 0.96
# Weighted Average F1 Score: 0.96

# %%
import seaborn as sns
import matplotlib.pyplot as plt

conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

class_names = ["Web","Video","Social","Email","Doc","Microsoft","Chat","VoIP","Gaming","Background"]
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names,annot_kws={"size": 14})
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('True', fontsize=14)
plt.title('Confusion Matrix')
plt.savefig('40 >40 confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

class_names = ["Web","Video","Social","Email","Doc","Microsoft","Chat","VoIP","Gaming","Background"]
plt.figure(figsize=(8, 6))
annot_kws = {"size": 11}
ax = sns.heatmap(conf_matrix_percentage, annot=True, fmt='.1f', cmap='Blues', xticklabels=class_names, yticklabels=class_names,annot_kws=annot_kws)
for t in ax.texts: t.set_text(t.get_text() + " %")
plt.xlabel('Predicted', fontsize=14)  
plt.ylabel('True', fontsize=14)
plt.title('Confusion Matrix')
plt.savefig('40 >40 confusion_matrixpercent.png', dpi=300, bbox_inches='tight')
plt.show()
