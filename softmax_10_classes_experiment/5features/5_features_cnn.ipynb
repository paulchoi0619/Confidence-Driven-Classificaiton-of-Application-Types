# %%
import os
import sys

# %%
import json

with open("client_ip.json", "r") as f:
    client_ip = json.load(f)

# %%
import tensorflow as tf
# Out:
# 2025-06-19 13:29:51.298634: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750354191.315900 2821790 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750354191.321016 2821790 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1750354191.338285 2821790 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750354191.338312 2821790 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750354191.338314 2821790 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750354191.338316 2821790 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-19 13:29:51.343682: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/asyncio/base_events.py", line 1906, in _run_once
#     handle._run()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2821790/3793406994.py", line 1, in <module>
#     import tensorflow as tf
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/tensorflow/__init__.py", line 468, in <module>
#     importlib.import_module("keras.src.optimizers")
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/__init__.py", line 2, in <module>
#     from keras.api import DTypePolicy
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/api/__init__.py", line 8, in <module>
#     from keras.api import activations
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/api/activations/__init__.py", line 7, in <module>
#     from keras.src.activations import deserialize
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/__init__.py", line 1, in <module>
#     from keras.src import activations
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/activations/__init__.py", line 33, in <module>
#     from keras.src.saving import object_registration
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/saving/__init__.py", line 7, in <module>
#     from keras.src.saving.saving_api import load_model
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/saving/saving_api.py", line 7, in <module>
#     from keras.src.legacy.saving import legacy_h5_format
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/legacy/saving/legacy_h5_format.py", line 13, in <module>
#     from keras.src.legacy.saving import saving_utils
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/legacy/saving/saving_utils.py", line 10, in <module>
#     from keras.src import models
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/models/__init__.py", line 1, in <module>
#     from keras.src.models.functional import Functional
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/models/functional.py", line 16, in <module>
#     from keras.src.models.model import Model
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/models/model.py", line 12, in <module>
#     from keras.src.trainers import trainer as base_trainer
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/trainers/trainer.py", line 14, in <module>
#     from keras.src.trainers.data_adapters import data_adapter_utils
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/trainers/data_adapters/__init__.py", line 4, in <module>
#     from keras.src.trainers.data_adapters import array_data_adapter
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 7, in <module>
#     from keras.src.trainers.data_adapters import array_slicing
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_slicing.py", line 12, in <module>
#     import pandas
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 50, in <module>
#     from pandas.core import (
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/ops/__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/ops/array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/numexpr/__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/asyncio/base_events.py", line 1906, in _run_once
#     handle._run()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2821790/3793406994.py", line 1, in <module>
#     import tensorflow as tf
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/tensorflow/__init__.py", line 468, in <module>
#     importlib.import_module("keras.src.optimizers")
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/__init__.py", line 2, in <module>
#     from keras.api import DTypePolicy
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/api/__init__.py", line 8, in <module>
#     from keras.api import activations
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/api/activations/__init__.py", line 7, in <module>
#     from keras.src.activations import deserialize
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/__init__.py", line 1, in <module>
#     from keras.src import activations
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/activations/__init__.py", line 33, in <module>
#     from keras.src.saving import object_registration
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/saving/__init__.py", line 7, in <module>
#     from keras.src.saving.saving_api import load_model
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/saving/saving_api.py", line 7, in <module>
#     from keras.src.legacy.saving import legacy_h5_format
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/legacy/saving/legacy_h5_format.py", line 13, in <module>
#     from keras.src.legacy.saving import saving_utils
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/legacy/saving/saving_utils.py", line 10, in <module>
#     from keras.src import models
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/models/__init__.py", line 1, in <module>
#     from keras.src.models.functional import Functional
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/models/functional.py", line 16, in <module>
#     from keras.src.models.model import Model
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/models/model.py", line 12, in <module>
#     from keras.src.trainers import trainer as base_trainer
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/trainers/trainer.py", line 14, in <module>
#     from keras.src.trainers.data_adapters import data_adapter_utils
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/trainers/data_adapters/__init__.py", line 4, in <module>
#     from keras.src.trainers.data_adapters import array_data_adapter
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 7, in <module>
#     from keras.src.trainers.data_adapters import array_slicing
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_slicing.py", line 12, in <module>
#     import pandas
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/nas/longleaf/home/paulchoi/.local/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %%
module_path = os.path.abspath('../method/preprocess.py')
module_dir = os.path.dirname(module_path)
if module_dir not in sys.path:
    sys.path.append(module_dir)
module_path = os.path.abspath('../transformation/transformation.py')
module_dir = os.path.dirname(module_path)
if module_dir not in sys.path:
    sys.path.append(module_dir)

# %%
from preprocess import train_traffic_csv_converter
from preprocess import test_traffic_csv_converter
from preprocess import iterate_over_files_in_directory

# %%
batch_size = 128
features = 40
input_shape = (features,2)

# %%
import matplotlib.pyplot as plt
import numpy as np
WINDOW=40
def lstm_vector(ts1,sizes1,ts2,sizes2,s_port,d_port,voip=False):
    #determine direction
    if voip:
        src_ts = ts1
        src_sizes = sizes1
        dst_ts = ts2
        dst_sizes = sizes2
        src_port = s_port
        dst_port = d_port
    else:
        if ts1[0]<ts2[0]:
            src_ts = ts1
            src_sizes = sizes1
            dst_ts = ts2
            dst_sizes = sizes2
            src_port = s_port
            dst_port = d_port
        else:
            src_ts = ts2
            src_sizes = sizes2
            dst_ts = ts1
            dst_sizes = sizes1
            src_port = d_port
            dst_port = s_port
    array = []
    j = 0 #src
    k = 0 #dst
    min_val = min(src_ts[0],dst_ts[0])
    length = len(src_ts)+len(dst_ts)
    for i in range(40):
        if j>=len(src_ts) and k>=len(dst_ts):
            break
        if j>=len(src_ts):
            array.append([round(dst_ts[k]-min_val,6),dst_sizes[k],dst_port,src_port,1])
            k+=1
        elif k >= len(dst_ts):
            array.append([round(src_ts[j]-min_val,6),src_sizes[j],src_port,dst_port,0]) 
            j+=1
        elif src_ts[j]<=dst_ts[k]:
            array.append([round(src_ts[j]-min_val,6),src_sizes[j],src_port,dst_port,0]) 
            j+=1
        else:
            array.append([round(dst_ts[k]-min_val,6),dst_sizes[k],dst_port,src_port,1])
            k+=1
    # for i in range(WINDOW-length):
    #      array.append([0,0])
    array = np.array(array)
    X = array.reshape(-1,5)
    return X

# %%
WINDOW=50
def seq_50(ts1,sizes1,ts2,sizes2,s_port,d_port):
    #determine direction
    if ts1[0]<ts2[0]:
        src_ts = ts1
        src_sizes = sizes1
        dst_ts = ts2
        dst_sizes = sizes2
        src_port = s_port
        dst_port = d_port
    else:
        src_ts = ts2
        src_sizes = sizes2
        dst_ts = ts1
        dst_sizes = sizes1
        src_port = d_port
        dst_port = s_port
    array = []
    j = 0 #src
    k = 0 #dst
    min_val = min(src_ts[0],dst_ts[0])
    for i in range(WINDOW):
        if j>=len(src_ts) and k>=len(dst_ts):
            break
        if j>=len(src_ts):
            array.append([round(dst_ts[k]-min_val,6),dst_sizes[k],dst_port,src_port,1])
            k+=1
        elif k >= len(dst_ts):
            array.append([round(src_ts[j]-min_val,6),src_sizes[j],src_port,dst_port,0]) 
            j+=1
        elif src_ts[j]<=dst_ts[k]:
            array.append([round(src_ts[j]-min_val,6),src_sizes[j],src_port,dst_port,0]) 
            j+=1
        else:
            array.append([round(dst_ts[k]-min_val,6),dst_sizes[k],dst_port,src_port,1])
            k+=1
    for i in range(WINDOW-len(array)):
         array.append([0,0,0,0,0])
    array = np.array(array)
    X = array.reshape(-1,5)
    return X

# %%
def check_strings_in_classname(classname):
    keywords = {
    "web": 0, "video": 1, "social": 2, "email": 3,"voip":4,"chat":5,"gaming":6,"docs":7
    }
    for keyword in keywords:
        if keyword in classname:
            return keywords[keyword] 
    return None

# %%
# check_path = os.path.join(checkpoint_dir, MODEL_NAME + 'pseudo_labeled_binary_lstm_acc.weights.h5')
# pipeline.named_steps['model'].load_weights(check_path)

# %%
X_train = []
y_train = []
voip = []
gaming = []
web = []
video = []
social = []
email = []
doc = []
microsoft = []
chat = []
background = []

# %%
path2 = os.path.abspath('..')

# %%
import os
import csv
import tensorflow as tf

folder_path = path2+"/labeled_train"

# %%
import json
def traffic_csv_converter(file_path):
    X_train = []
    y_train = []
    with open(file_path, 'r') as csv_file:
        reader = csv.reader(csv_file)
        filename = os.path.splitext(os.path.basename(file_path))[0]
        flow_val = {}
        class_val = {}
        paired_keys = set()
        for i, row in enumerate(reader):
            class_name = row[0]
            src_ip = row[1]
            src_port = row[2]
            dst_ip = row[3]
            dst_port = row[4]
            length = int(row[7])
            ts = np.array(row[8:8+length], dtype=float)
            sizes = np.array(row[9+length:], dtype=int)
            key = (src_ip, src_port, dst_ip, dst_port)
            reverse_key = (dst_ip, dst_port, src_ip, src_port)
            if reverse_key in flow_val:
                # Found the reverse flow
                opposite_ts, opposite_sizes,s_port,d_port = flow_val.pop(reverse_key)
                paired_keys.add(key)
                paired_keys.add(reverse_key)
                if len(opposite_ts) + len(ts) < 40: #flow too small
                    continue
                if "voip" in file_path and class_name =="voip":
                    if reverse_key[0] in client_ip:
                        src_ts, src_sizes = opposite_ts, opposite_sizes
                        src_port,dst_port = s_port,d_port
                        dst_ts, dst_sizes = ts, sizes
                    else:
                        src_ts, src_sizes = ts, sizes
                        dst_ts, dst_sizes = opposite_ts, opposite_sizes
                    x = lstm_vector(src_ts, src_sizes, dst_ts, dst_sizes,src_port,dst_port,True)
                    v = seq_50(src_ts, src_sizes, dst_ts, dst_sizes,src_port,dst_port)
                else:
                    src_ts, src_sizes = opposite_ts, opposite_sizes
                    dst_ts, dst_sizes = ts, sizes
                    x = lstm_vector(src_ts, src_sizes, dst_ts, dst_sizes,src_port,dst_port)
                    v = seq_50(src_ts, src_sizes, dst_ts, dst_sizes,src_port,dst_port)
                if "voip" in file_path and class_name == "voip":
                    voip.append(v)
                    y_train.append(7)
                elif "gaming" in file_path:
                    gaming.append(v)
                    y_train.append(8)
                elif class_name == "web":
                    web.append(v)
                    y_train.append(0)
                elif class_name == "video":
                    video.append(v)
                    y_train.append(1)
                elif class_name == "social":
                    social.append(v)
                    y_train.append(2)
                elif class_name == "email":
                    email.append(v)
                    y_train.append(3)
                elif class_name == "doc":
                    doc.append(v)
                    y_train.append(4)
                elif class_name == "microsoft":
                    microsoft.append(v)
                    y_train.append(5)
                elif class_name == "chat":
                    chat.append(v)
                    y_train.append(6)
                else: #background_flow
                    background.append(v)
                    y_train.append(9)
                X_train.append(x)
            else:
                # Save forward direction flow
                flow_val[key] = (ts, sizes,src_port,dst_port)
                class_val[key] = class_name
    for key, value in flow_val.items():
        if len(value[0]) >= 40:
            if "voip" in file_path:
                ts = value[0][:40]
                sizes = value[1][:40]
                src_port = value[2]
                dst_port = value[3]
                if key[0] in client_ip:
                    sizes = value[1][:40]
                else:
                    sizes = -value[1][:40]
                s_port = np.repeat(src_port,  40) 
                d_port = np.repeat(dst_port,  40) 
                zeros = np.zeros(40)  
                
                v = np.column_stack([ts, sizes,s_port,d_port,zeros])
                X_train.append(v)
                if class_val[key] == "voip": #if the flow is unique
                    y_train.append(7)
                else:
                    y_train.append(9) #if the flow is background
                
                ts = value[0][:50]
                if key[0] in client_ip:
                    sizes = value[1][:50]
                else:
                    sizes = -value[1][:50]
                if len(ts)<50:
                    pad = 50 - len(ts)
                    ts    = np.pad(ts,    (0, pad), mode="constant", constant_values=0)
                    sizes = np.pad(sizes, (0, pad), mode="constant", constant_values=0)
                s_port = np.repeat(src_port,  50)  
                d_port = np.repeat(dst_port,  50)   
                zeros = np.zeros(50)  
                
                v = np.column_stack([ts, sizes,s_port,d_port,zeros])
                if class_val[key] == "voip":
                    voip.append(v)
            elif "gaming" in file_path:
                ts = value[0][:40]
                sizes = value[1][:40]
                src_port =value[2]
                dst_port = value[3]
                s_port = np.repeat(src_port,  40)
                d_port = np.repeat(dst_port,  40)  
                zeros = np.zeros(40)
                
                v = np.column_stack([ts, sizes,s_port,d_port,zeros])
                X_train.append(v)
                y_train.append(8)
                
                ts = value[0][:50]
                sizes = value[1][:50]
                if len(ts)<50:
                    pad = 50 - len(ts)
                    ts    = np.pad(ts,    (0, pad), mode="constant", constant_values=0)
                    sizes = np.pad(sizes, (0, pad), mode="constant", constant_values=0)
                s_port = np.repeat(src_port,  50)  
                d_port = np.repeat(dst_port,  50)  
                zeros = np.zeros(50)
                v = np.column_stack([ts, sizes,s_port,d_port,zeros])
                gaming.append(v)
            
            
    return X_train, y_train
def iterate_over_files_in_directory(directory):
    for file_name in os.listdir(directory):
        if file_name.endswith(".csv"):  # You can adjust the file extension if needed
            file_path = os.path.join(directory, file_name)
            yield file_path

# %%
docs_path = folder_path + "/docs"
for file_path in iterate_over_files_in_directory(docs_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
web_path = folder_path + "/web"
for file_path in iterate_over_files_in_directory(web_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
chat_path = folder_path + "/chat"
for file_path in iterate_over_files_in_directory(chat_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
social_path = folder_path + "/social"
for file_path in iterate_over_files_in_directory(social_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
video_path = folder_path + "/video"
for file_path in iterate_over_files_in_directory(video_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
voip_path = folder_path + "/voip"
for file_path in iterate_over_files_in_directory(voip_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
gaming_path = folder_path + "/gaming"
for file_path in iterate_over_files_in_directory(gaming_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)
email_path = folder_path + "/email"
for file_path in iterate_over_files_in_directory(email_path):
        X,y = traffic_csv_converter(file_path)
        X_train.extend(X)
        y_train.extend(y)

# %%
import numpy as np

# %%
X_dataset = np.array(X_train)

# %%
y_dataset = np.array(y_train)

# %%
from collections import Counter
counter = Counter(y_dataset)
counts = [counter.get(i, 0) for i in range(10)]

# %%
max_val = max(counts)

# %%
max_val
# Out:
# 24545

# %%
counts
# Out:
# [2697, 466, 792, 113, 116, 239, 54, 289, 1006, 24545]

# %%
def translation(X):
    arrival_times = X
    n,time_steps,features = arrival_times.shape
    for i in range(n):
        threshold_indices = [2,4,6,8,10] 
        max_n =np.random.choice(threshold_indices) 
        n = np.random.randint(1, max_n + 1)  # Shift 1 to `max_n` packets
        t = np.random.randint(0, 40) 
        direction = np.random.choice(['left', 'right'])
        if direction == 'left':
            total_length = arrival_times.shape[1]
            start_index = t-n
            if start_index < 0: 
                valid_portion = arrival_times[i, t - start_index:50]
                assigned_value = valid_portion.shape[0]
                arrival_times[i, 0:assigned_value] = valid_portion
                arrival_times[i, assigned_value+1:] = 0 
            else:
                valid_portion = arrival_times[i, t:(50)]
                assigned_value = arrival_times[i, start_index:50].shape
                zeros = np.zeros((assigned_value[0]-valid_portion.shape[0],5))
                arrival_times[i, start_index:50] = np.concatenate((valid_portion, zeros))  # bounded to the right by 50
            
        else:
            t_val = arrival_times[i, t] 
            last_index = min(t + n, 40) 
            first_val = min(last_index + n, 40)  
            num_to_shift = last_index - t  
            available_space = 40 - first_val 
            if num_to_shift > 0:
                shift_amount = min(num_to_shift, available_space)
                arrival_times[i, first_val:first_val + shift_amount] = arrival_times[i, t:t + shift_amount]
            arrival_times[i, t:last_index] = t_val
    return arrival_times

# %%
voip = np.array(voip)
gaming = np.array(gaming)
web = np.array(web)
video = np.array(video)
social = np.array(social)
email = np.array(email)
doc = np.array(doc)
microsoft = np.array(microsoft)
chat = np.array(chat)
background = np.array(background)

# %%
for i in range(9):
    if i == 0:
        sample = web
    elif i == 1:
        sample = video
    elif i == 2:
        sample = social
    elif i == 3:
        sample = email
    elif i == 4:
        sample = doc
    elif i == 5:
        sample = microsoft
    elif i == 6:
        sample = chat
    elif i == 7:
        sample = voip
    elif i == 8:
        sample = gaming
    indices = tf.range(sample.shape[0])
    value = len(sample)
    sampled_indices = np.random.choice(indices, max_val-value, replace=True)
    sampled_X = sample[sampled_indices]
    augmented = translation(sampled_X)
    augmented = augmented[:, :40, :]
    X_dataset = np.vstack((X_dataset,augmented))
    y = np.array([i]*(max_val-value))
    y_dataset = np.concatenate((y_dataset,y))

# %%
X_train = np.load('X_train.npy')
y_train = np.load('y_train.npy')
X_val = np.load('X_val.npy')
y_val = np.load('y_val.npy')

# %%
from keras.utils import to_categorical

# %%
X_dataset = np.array(X_dataset)
y_dataset = np.array(y_dataset)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_dataset, y_dataset, test_size=0.2, random_state=42)

# %%
X_train = X_train.astype(np.float32)
X_val   = X_val.astype(np.float32)

# %%
y_train = to_categorical(y_train, num_classes=10)
y_val = to_categorical(y_val, num_classes=10)

# %%
num_classes = 10

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import TensorBoard, ModelCheckpoint
from keras.models import Sequential
from tensorflow.keras.models import Model
from keras.layers import Concatenate,RepeatVector,GlobalAveragePooling1D,Reshape,MaxPooling2D,ReLU,Input,InputLayer,Conv1D, MaxPooling1D, Flatten, Dense, Dropout,LSTM,BatchNormalization,Bidirectional,LayerNormalization
from keras import backend as K
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from keras.metrics import top_k_categorical_accuracy
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras.backend as K
path = os.path.abspath('')


def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def f1_score(y_true, y_pred):
    prec = precision(y_true, y_pred)
    rec = recall(y_true, y_pred)
    return 2 * ((prec * rec) / (prec + rec))

# def top_2_categorical_accuracy(y_true, y_pred):
#     return top_k_categorical_accuracy(y_true, y_pred, k=2)

# Custom transformer to transpose data

# Set the ratio for the train-test split


# Create a scikit-learn pipeline
def build_cnn_rnn_2a(
    seq_len: int,
    num_features: int,
    num_classes: int
) -> tf.keras.Model:
    """
    CNN + single-layer LSTM (2A variant):
      conv1d(32, k=4, s=2, p='same') → BN
      conv1d(64, k=4, s=2, p='same') → BN
      LSTM(100)
      Dense(100, relu)
      Dense(num_classes, softmax)
    """
    inp = Input((seq_len, num_features), name="flow_input")
    
    # 1) First conv block
    x = Conv1D(32, 4, strides=2, padding="same", activation="gelu")(inp)
    x = BatchNormalization()(x)
    
    # 2) Global branch on the *original* conv output (before any pooling)
    x_global = GlobalAveragePooling1D()(x)        # (batch, 32)
    down_len = seq_len // 4                       # e.g. 40//4 = 10
    x_global_seq = RepeatVector(down_len)(x_global)  # (batch, 10, 32)
    
    # 3) Local branch: now do the max‐pooling
    x_local = MaxPooling1D(pool_size=2)(x)        # (batch, 10, 32)
    x_local = Dropout(0.1)(x_local)
    
    # 4) Fuse local + global
    x = Concatenate(axis=-1)([x_local, x_global_seq])  # (batch, 10, 64)
    
    # 5) LSTM → head
    x = LSTM(64, name="lstm")(x)
    x = Dropout(0.1, name="dropout_lstm")(x)
    x = Dense(64, activation="gelu", name="fc1")(x)
    outputs = Dense(num_classes, activation="softmax", name="classifier")(x)
    return Model(inp, outputs, name="CNN_GlobalBeforeMax")

pipeline = build_cnn_rnn_2a(40,5,10)

# Set up callbacks
checkpoint_dir = os.path.abspath('')+"/tensorboard"
log_dir = os.path.abspath('') + "/log"
MODEL_NAME = "checkpoint"
check_path = os.path.join(checkpoint_dir, MODEL_NAME + 'cnn_lstm_loss.weights.h5')
tensorboard = TensorBoard(log_dir='./Graph', histogram_freq=1, write_graph=True,
                          write_images=True)
checkpointer_loss = ModelCheckpoint(filepath=check_path, verbose=1, save_best_only=True,
                                     save_weights_only=True)
checkpointer_acc = ModelCheckpoint(monitor='val_f1_score', filepath= os.path.join(checkpoint_dir, MODEL_NAME + 'cnn_lstm_acc.weights.h5'), verbose=1,
                                    save_best_only=True, save_weights_only=True,mode='max')
tensorboard.set_model(pipeline)

early_stopping = EarlyStopping(monitor='val_f1_score', patience=50, restore_best_weights=True,mode='max')
# Out:
# W0000 00:00:1750354210.262636 2821790 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
pipeline.compile(loss='categorical_crossentropy',
                                      optimizer='adam',
                                      metrics=['accuracy', f1_score, precision, recall])

# %%
history = pipeline.fit(X_train, y_train, epochs=500, batch_size=batch_size, callbacks=[early_stopping,tensorboard, checkpointer_loss, checkpointer_acc],
         validation_data=(X_val, y_val))
# Out:
# Epoch 1/500
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4835 - f1_score: nan - loss: 1.3845 - precision: 0.7287 - recall: 0.2939
# Epoch 1: val_loss improved from inf to 1.34279, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 1: val_f1_score improved from -inf to 0.45828, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.4836 - f1_score: nan - loss: 1.3843 - precision: 0.7287 - recall: 0.2940 - val_accuracy: 0.5134 - val_f1_score: 0.4583 - val_loss: 1.3428 - val_precision: 0.6754 - val_recall: 0.3477
# Epoch 2/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7279 - f1_score: 0.7173 - loss: 0.7489 - precision: 0.8279 - recall: 0.6338
# Epoch 2: val_loss improved from 1.34279 to 1.15290, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 2: val_f1_score improved from 0.45828 to 0.59652, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.7279 - f1_score: 0.7173 - loss: 0.7488 - precision: 0.8279 - recall: 0.6338 - val_accuracy: 0.6141 - val_f1_score: 0.5965 - val_loss: 1.1529 - val_precision: 0.7280 - val_recall: 0.5060
# Epoch 3/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7868 - f1_score: 0.7836 - loss: 0.5933 - precision: 0.8590 - recall: 0.7210
# Epoch 3: val_loss improved from 1.15290 to 0.92990, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 3: val_f1_score improved from 0.59652 to 0.67454, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.7868 - f1_score: 0.7836 - loss: 0.5932 - precision: 0.8590 - recall: 0.7210 - val_accuracy: 0.6806 - val_f1_score: 0.6745 - val_loss: 0.9299 - val_precision: 0.7639 - val_recall: 0.6044
# Epoch 4/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8183 - f1_score: 0.8168 - loss: 0.4998 - precision: 0.8749 - recall: 0.7664
# Epoch 4: val_loss did not improve from 0.92990
#
# Epoch 4: val_f1_score did not improve from 0.67454
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.8183 - f1_score: 0.8168 - loss: 0.4998 - precision: 0.8749 - recall: 0.7664 - val_accuracy: 0.5609 - val_f1_score: 0.5592 - val_loss: 1.4900 - val_precision: 0.6343 - val_recall: 0.5005
# Epoch 5/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8403 - f1_score: 0.8392 - loss: 0.4435 - precision: 0.8853 - recall: 0.7980
# Epoch 5: val_loss did not improve from 0.92990
#
# Epoch 5: val_f1_score did not improve from 0.67454
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.8403 - f1_score: 0.8392 - loss: 0.4434 - precision: 0.8853 - recall: 0.7980 - val_accuracy: 0.6515 - val_f1_score: 0.6473 - val_loss: 1.0875 - val_precision: 0.7275 - val_recall: 0.5836
# Epoch 6/500
# 1532/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8528 - f1_score: 0.8515 - loss: 0.4093 - precision: 0.8913 - recall: 0.8155
# Epoch 6: val_loss did not improve from 0.92990
#
# Epoch 6: val_f1_score improved from 0.67454 to 0.69826, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.8528 - f1_score: 0.8515 - loss: 0.4093 - precision: 0.8913 - recall: 0.8155 - val_accuracy: 0.6967 - val_f1_score: 0.6983 - val_loss: 0.9394 - val_precision: 0.7540 - val_recall: 0.6506
# Epoch 7/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8621 - f1_score: 0.8618 - loss: 0.3816 - precision: 0.8966 - recall: 0.8299
# Epoch 7: val_loss improved from 0.92990 to 0.82803, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 7: val_f1_score improved from 0.69826 to 0.72670, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.8621 - f1_score: 0.8618 - loss: 0.3816 - precision: 0.8966 - recall: 0.8299 - val_accuracy: 0.7249 - val_f1_score: 0.7267 - val_loss: 0.8280 - val_precision: 0.7762 - val_recall: 0.6835
# Epoch 8/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8694 - f1_score: 0.8702 - loss: 0.3589 - precision: 0.9004 - recall: 0.8421
# Epoch 8: val_loss improved from 0.82803 to 0.81639, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 8: val_f1_score improved from 0.72670 to 0.73894, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.8694 - f1_score: 0.8702 - loss: 0.3589 - precision: 0.9004 - recall: 0.8421 - val_accuracy: 0.7364 - val_f1_score: 0.7389 - val_loss: 0.8164 - val_precision: 0.7828 - val_recall: 0.7001
# Epoch 9/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8745 - f1_score: 0.8755 - loss: 0.3452 - precision: 0.9029 - recall: 0.8500
# Epoch 9: val_loss improved from 0.81639 to 0.69415, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 9: val_f1_score improved from 0.73894 to 0.77485, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.8745 - f1_score: 0.8755 - loss: 0.3452 - precision: 0.9029 - recall: 0.8500 - val_accuracy: 0.7730 - val_f1_score: 0.7748 - val_loss: 0.6941 - val_precision: 0.8199 - val_recall: 0.7348
# Epoch 10/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8761 - f1_score: 0.8764 - loss: 0.3442 - precision: 0.9039 - recall: 0.8507
# Epoch 10: val_loss did not improve from 0.69415
#
# Epoch 10: val_f1_score did not improve from 0.77485
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.8761 - f1_score: 0.8764 - loss: 0.3442 - precision: 0.9039 - recall: 0.8507 - val_accuracy: 0.7631 - val_f1_score: 0.7664 - val_loss: 0.7150 - val_precision: 0.8053 - val_recall: 0.7313
# Epoch 11/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8877 - f1_score: 0.8880 - loss: 0.3103 - precision: 0.9107 - recall: 0.8666
# Epoch 11: val_loss did not improve from 0.69415
#
# Epoch 11: val_f1_score did not improve from 0.77485
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.8877 - f1_score: 0.8880 - loss: 0.3103 - precision: 0.9107 - recall: 0.8666 - val_accuracy: 0.6075 - val_f1_score: 0.6103 - val_loss: 1.4466 - val_precision: 0.6564 - val_recall: 0.5705
# Epoch 12/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8906 - f1_score: 0.8906 - loss: 0.3023 - precision: 0.9128 - recall: 0.8696
# Epoch 12: val_loss improved from 0.69415 to 0.59995, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 12: val_f1_score improved from 0.77485 to 0.79911, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.8906 - f1_score: 0.8906 - loss: 0.3023 - precision: 0.9128 - recall: 0.8696 - val_accuracy: 0.7964 - val_f1_score: 0.7991 - val_loss: 0.6000 - val_precision: 0.8337 - val_recall: 0.7675
# Epoch 13/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8927 - f1_score: 0.8937 - loss: 0.2920 - precision: 0.9148 - recall: 0.8738
# Epoch 13: val_loss improved from 0.59995 to 0.49259, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 13: val_f1_score improved from 0.79911 to 0.83401, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.8927 - f1_score: 0.8937 - loss: 0.2920 - precision: 0.9148 - recall: 0.8738 - val_accuracy: 0.8320 - val_f1_score: 0.8340 - val_loss: 0.4926 - val_precision: 0.8629 - val_recall: 0.8072
# Epoch 14/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8982 - f1_score: 0.8985 - loss: 0.2835 - precision: 0.9173 - recall: 0.8806
# Epoch 14: val_loss did not improve from 0.49259
#
# Epoch 14: val_f1_score did not improve from 0.83401
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.8982 - f1_score: 0.8985 - loss: 0.2835 - precision: 0.9173 - recall: 0.8806 - val_accuracy: 0.8268 - val_f1_score: 0.8279 - val_loss: 0.5316 - val_precision: 0.8544 - val_recall: 0.8031
# Epoch 15/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9000 - f1_score: 0.9003 - loss: 0.2763 - precision: 0.9191 - recall: 0.8823
# Epoch 15: val_loss improved from 0.49259 to 0.39785, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 15: val_f1_score improved from 0.83401 to 0.86165, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9000 - f1_score: 0.9003 - loss: 0.2763 - precision: 0.9191 - recall: 0.8823 - val_accuracy: 0.8600 - val_f1_score: 0.8617 - val_loss: 0.3978 - val_precision: 0.8861 - val_recall: 0.8387
# Epoch 16/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9035 - f1_score: 0.9039 - loss: 0.2668 - precision: 0.9210 - recall: 0.8875
# Epoch 16: val_loss did not improve from 0.39785
#
# Epoch 16: val_f1_score did not improve from 0.86165
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9035 - f1_score: 0.9039 - loss: 0.2668 - precision: 0.9210 - recall: 0.8874 - val_accuracy: 0.7758 - val_f1_score: 0.7790 - val_loss: 0.7129 - val_precision: 0.8079 - val_recall: 0.7522
# Epoch 17/500
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9053 - f1_score: 0.9058 - loss: 0.2636 - precision: 0.9228 - recall: 0.8897
# Epoch 17: val_loss did not improve from 0.39785
#
# Epoch 17: val_f1_score did not improve from 0.86165
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9053 - f1_score: 0.9058 - loss: 0.2636 - precision: 0.9228 - recall: 0.8897 - val_accuracy: 0.8313 - val_f1_score: 0.8324 - val_loss: 0.5006 - val_precision: 0.8603 - val_recall: 0.8065
# Epoch 18/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9056 - f1_score: 0.9059 - loss: 0.2603 - precision: 0.9226 - recall: 0.8899
# Epoch 18: val_loss did not improve from 0.39785
#
# Epoch 18: val_f1_score did not improve from 0.86165
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9056 - f1_score: 0.9059 - loss: 0.2603 - precision: 0.9226 - recall: 0.8899 - val_accuracy: 0.8599 - val_f1_score: 0.8611 - val_loss: 0.4074 - val_precision: 0.8852 - val_recall: 0.8385
# Epoch 19/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9067 - f1_score: 0.9068 - loss: 0.2585 - precision: 0.9232 - recall: 0.8911
# Epoch 19: val_loss improved from 0.39785 to 0.36267, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 19: val_f1_score improved from 0.86165 to 0.87649, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9067 - f1_score: 0.9068 - loss: 0.2585 - precision: 0.9232 - recall: 0.8911 - val_accuracy: 0.8759 - val_f1_score: 0.8765 - val_loss: 0.3627 - val_precision: 0.8942 - val_recall: 0.8596
# Epoch 20/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9110 - f1_score: 0.9114 - loss: 0.2483 - precision: 0.9265 - recall: 0.8969
# Epoch 20: val_loss did not improve from 0.36267
#
# Epoch 20: val_f1_score did not improve from 0.87649
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9110 - f1_score: 0.9114 - loss: 0.2483 - precision: 0.9265 - recall: 0.8969 - val_accuracy: 0.8698 - val_f1_score: 0.8716 - val_loss: 0.3825 - val_precision: 0.8876 - val_recall: 0.8564
# Epoch 21/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9115 - f1_score: 0.9117 - loss: 0.2455 - precision: 0.9265 - recall: 0.8975
# Epoch 21: val_loss improved from 0.36267 to 0.30809, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 21: val_f1_score improved from 0.87649 to 0.89556, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9115 - f1_score: 0.9117 - loss: 0.2455 - precision: 0.9265 - recall: 0.8975 - val_accuracy: 0.8953 - val_f1_score: 0.8956 - val_loss: 0.3081 - val_precision: 0.9098 - val_recall: 0.8818
# Epoch 22/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9160 - f1_score: 0.9164 - loss: 0.2340 - precision: 0.9300 - recall: 0.9034
# Epoch 22: val_loss improved from 0.30809 to 0.26336, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 22: val_f1_score improved from 0.89556 to 0.90843, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9160 - f1_score: 0.9164 - loss: 0.2340 - precision: 0.9300 - recall: 0.9034 - val_accuracy: 0.9070 - val_f1_score: 0.9084 - val_loss: 0.2634 - val_precision: 0.9221 - val_recall: 0.8953
# Epoch 23/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9140 - f1_score: 0.9144 - loss: 0.2358 - precision: 0.9282 - recall: 0.9011
# Epoch 23: val_loss improved from 0.26336 to 0.24791, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 23: val_f1_score improved from 0.90843 to 0.91452, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9140 - f1_score: 0.9144 - loss: 0.2358 - precision: 0.9282 - recall: 0.9011 - val_accuracy: 0.9137 - val_f1_score: 0.9145 - val_loss: 0.2479 - val_precision: 0.9263 - val_recall: 0.9031
# Epoch 24/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9179 - f1_score: 0.9187 - loss: 0.2272 - precision: 0.9315 - recall: 0.9062
# Epoch 24: val_loss did not improve from 0.24791
#
# Epoch 24: val_f1_score did not improve from 0.91452
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9179 - f1_score: 0.9187 - loss: 0.2272 - precision: 0.9315 - recall: 0.9062 - val_accuracy: 0.8563 - val_f1_score: 0.8578 - val_loss: 0.4328 - val_precision: 0.8746 - val_recall: 0.8417
# Epoch 25/500
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9193 - f1_score: 0.9197 - loss: 0.2217 - precision: 0.9324 - recall: 0.9075
# Epoch 25: val_loss improved from 0.24791 to 0.21972, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 25: val_f1_score improved from 0.91452 to 0.92301, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9193 - f1_score: 0.9197 - loss: 0.2217 - precision: 0.9324 - recall: 0.9075 - val_accuracy: 0.9226 - val_f1_score: 0.9230 - val_loss: 0.2197 - val_precision: 0.9344 - val_recall: 0.9120
# Epoch 26/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9209 - f1_score: 0.9210 - loss: 0.2195 - precision: 0.9336 - recall: 0.9089
# Epoch 26: val_loss did not improve from 0.21972
#
# Epoch 26: val_f1_score did not improve from 0.92301
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9209 - f1_score: 0.9210 - loss: 0.2195 - precision: 0.9336 - recall: 0.9089 - val_accuracy: 0.8999 - val_f1_score: 0.9015 - val_loss: 0.2851 - val_precision: 0.9161 - val_recall: 0.8875
# Epoch 27/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9213 - f1_score: 0.9218 - loss: 0.2207 - precision: 0.9342 - recall: 0.9098
# Epoch 27: val_loss did not improve from 0.21972
#
# Epoch 27: val_f1_score did not improve from 0.92301
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9214 - f1_score: 0.9218 - loss: 0.2207 - precision: 0.9342 - recall: 0.9098 - val_accuracy: 0.9049 - val_f1_score: 0.9051 - val_loss: 0.2775 - val_precision: 0.9178 - val_recall: 0.8928
# Epoch 28/500
# 1532/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9220 - f1_score: 0.9224 - loss: 0.2168 - precision: 0.9341 - recall: 0.9111
# Epoch 28: val_loss did not improve from 0.21972
#
# Epoch 28: val_f1_score did not improve from 0.92301
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9220 - f1_score: 0.9224 - loss: 0.2168 - precision: 0.9341 - recall: 0.9111 - val_accuracy: 0.9172 - val_f1_score: 0.9184 - val_loss: 0.2374 - val_precision: 0.9303 - val_recall: 0.9070
# Epoch 29/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9236 - f1_score: 0.9240 - loss: 0.2144 - precision: 0.9363 - recall: 0.9120
# Epoch 29: val_loss did not improve from 0.21972
#
# Epoch 29: val_f1_score did not improve from 0.92301
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9236 - f1_score: 0.9240 - loss: 0.2144 - precision: 0.9363 - recall: 0.9120 - val_accuracy: 0.8980 - val_f1_score: 0.8988 - val_loss: 0.2983 - val_precision: 0.9117 - val_recall: 0.8863
# Epoch 30/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9225 - f1_score: 0.9231 - loss: 0.2148 - precision: 0.9347 - recall: 0.9120
# Epoch 30: val_loss did not improve from 0.21972
#
# Epoch 30: val_f1_score did not improve from 0.92301
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9225 - f1_score: 0.9231 - loss: 0.2148 - precision: 0.9347 - recall: 0.9120 - val_accuracy: 0.9162 - val_f1_score: 0.9178 - val_loss: 0.2370 - val_precision: 0.9286 - val_recall: 0.9073
# Epoch 31/500
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9252 - f1_score: 0.9253 - loss: 0.2088 - precision: 0.9369 - recall: 0.9141
# Epoch 31: val_loss did not improve from 0.21972
#
# Epoch 31: val_f1_score improved from 0.92301 to 0.92312, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9252 - f1_score: 0.9253 - loss: 0.2088 - precision: 0.9369 - recall: 0.9141 - val_accuracy: 0.9224 - val_f1_score: 0.9231 - val_loss: 0.2235 - val_precision: 0.9338 - val_recall: 0.9127
# Epoch 32/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9255 - f1_score: 0.9264 - loss: 0.2077 - precision: 0.9374 - recall: 0.9156
# Epoch 32: val_loss did not improve from 0.21972
#
# Epoch 32: val_f1_score did not improve from 0.92312
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9255 - f1_score: 0.9264 - loss: 0.2077 - precision: 0.9374 - recall: 0.9156 - val_accuracy: 0.8672 - val_f1_score: 0.8696 - val_loss: 0.3969 - val_precision: 0.8879 - val_recall: 0.8521
# Epoch 33/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9266 - f1_score: 0.9269 - loss: 0.2048 - precision: 0.9377 - recall: 0.9165
# Epoch 33: val_loss did not improve from 0.21972
#
# Epoch 33: val_f1_score did not improve from 0.92312
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9266 - f1_score: 0.9269 - loss: 0.2048 - precision: 0.9377 - recall: 0.9165 - val_accuracy: 0.8810 - val_f1_score: 0.8821 - val_loss: 0.3502 - val_precision: 0.8966 - val_recall: 0.8682
# Epoch 34/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9268 - f1_score: 0.9265 - loss: 0.2050 - precision: 0.9373 - recall: 0.9161
# Epoch 34: val_loss did not improve from 0.21972
#
# Epoch 34: val_f1_score improved from 0.92312 to 0.92318, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9268 - f1_score: 0.9265 - loss: 0.2050 - precision: 0.9373 - recall: 0.9161 - val_accuracy: 0.9220 - val_f1_score: 0.9232 - val_loss: 0.2229 - val_precision: 0.9338 - val_recall: 0.9129
# Epoch 35/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9289 - f1_score: 0.9290 - loss: 0.1979 - precision: 0.9392 - recall: 0.9190
# Epoch 35: val_loss did not improve from 0.21972
#
# Epoch 35: val_f1_score did not improve from 0.92318
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9289 - f1_score: 0.9290 - loss: 0.1979 - precision: 0.9392 - recall: 0.9190 - val_accuracy: 0.8502 - val_f1_score: 0.8522 - val_loss: 0.4642 - val_precision: 0.8720 - val_recall: 0.8334
# Epoch 36/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9247 - f1_score: 0.9253 - loss: 0.2084 - precision: 0.9362 - recall: 0.9147
# Epoch 36: val_loss did not improve from 0.21972
#
# Epoch 36: val_f1_score did not improve from 0.92318
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9247 - f1_score: 0.9253 - loss: 0.2084 - precision: 0.9362 - recall: 0.9147 - val_accuracy: 0.8933 - val_f1_score: 0.8946 - val_loss: 0.3131 - val_precision: 0.9064 - val_recall: 0.8832
# Epoch 37/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9298 - f1_score: 0.9301 - loss: 0.1960 - precision: 0.9404 - recall: 0.9202
# Epoch 37: val_loss did not improve from 0.21972
#
# Epoch 37: val_f1_score did not improve from 0.92318
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9298 - f1_score: 0.9301 - loss: 0.1960 - precision: 0.9404 - recall: 0.9202 - val_accuracy: 0.8988 - val_f1_score: 0.9003 - val_loss: 0.2956 - val_precision: 0.9121 - val_recall: 0.8888
# Epoch 38/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9277 - f1_score: 0.9278 - loss: 0.2029 - precision: 0.9384 - recall: 0.9175
# Epoch 38: val_loss did not improve from 0.21972
#
# Epoch 38: val_f1_score did not improve from 0.92318
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9277 - f1_score: 0.9278 - loss: 0.2029 - precision: 0.9384 - recall: 0.9175 - val_accuracy: 0.8976 - val_f1_score: 0.8981 - val_loss: 0.2989 - val_precision: 0.9087 - val_recall: 0.8877
# Epoch 39/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9311 - f1_score: 0.9316 - loss: 0.1897 - precision: 0.9408 - recall: 0.9227
# Epoch 39: val_loss did not improve from 0.21972
#
# Epoch 39: val_f1_score did not improve from 0.92318
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9311 - f1_score: 0.9316 - loss: 0.1897 - precision: 0.9408 - recall: 0.9227 - val_accuracy: 0.9177 - val_f1_score: 0.9182 - val_loss: 0.2359 - val_precision: 0.9272 - val_recall: 0.9094
# Epoch 40/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9320 - f1_score: 0.9322 - loss: 0.1904 - precision: 0.9419 - recall: 0.9229
# Epoch 40: val_loss did not improve from 0.21972
#
# Epoch 40: val_f1_score did not improve from 0.92318
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9320 - f1_score: 0.9322 - loss: 0.1904 - precision: 0.9419 - recall: 0.9229 - val_accuracy: 0.9053 - val_f1_score: 0.9068 - val_loss: 0.2777 - val_precision: 0.9181 - val_recall: 0.8958
# Epoch 41/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9314 - f1_score: 0.9317 - loss: 0.1896 - precision: 0.9412 - recall: 0.9224
# Epoch 41: val_loss did not improve from 0.21972
#
# Epoch 41: val_f1_score did not improve from 0.92318
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9314 - f1_score: 0.9317 - loss: 0.1896 - precision: 0.9412 - recall: 0.9224 - val_accuracy: 0.9169 - val_f1_score: 0.9174 - val_loss: 0.2386 - val_precision: 0.9273 - val_recall: 0.9078
# Epoch 42/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9313 - f1_score: 0.9319 - loss: 0.1914 - precision: 0.9412 - recall: 0.9228
# Epoch 42: val_loss did not improve from 0.21972
#
# Epoch 42: val_f1_score did not improve from 0.92318
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9313 - f1_score: 0.9319 - loss: 0.1914 - precision: 0.9412 - recall: 0.9228 - val_accuracy: 0.9041 - val_f1_score: 0.9058 - val_loss: 0.2824 - val_precision: 0.9184 - val_recall: 0.8935
# Epoch 43/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9326 - f1_score: 0.9333 - loss: 0.1881 - precision: 0.9423 - recall: 0.9245
# Epoch 43: val_loss improved from 0.21972 to 0.21098, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 43: val_f1_score improved from 0.92318 to 0.92798, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9326 - f1_score: 0.9333 - loss: 0.1881 - precision: 0.9423 - recall: 0.9245 - val_accuracy: 0.9266 - val_f1_score: 0.9280 - val_loss: 0.2110 - val_precision: 0.9372 - val_recall: 0.9190
# Epoch 44/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9328 - f1_score: 0.9331 - loss: 0.1871 - precision: 0.9425 - recall: 0.9240
# Epoch 44: val_loss did not improve from 0.21098
#
# Epoch 44: val_f1_score did not improve from 0.92798
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9328 - f1_score: 0.9331 - loss: 0.1871 - precision: 0.9425 - recall: 0.9240 - val_accuracy: 0.9165 - val_f1_score: 0.9176 - val_loss: 0.2432 - val_precision: 0.9268 - val_recall: 0.9086
# Epoch 45/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9329 - f1_score: 0.9340 - loss: 0.1850 - precision: 0.9426 - recall: 0.9256
# Epoch 45: val_loss did not improve from 0.21098
#
# Epoch 45: val_f1_score did not improve from 0.92798
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9329 - f1_score: 0.9340 - loss: 0.1850 - precision: 0.9426 - recall: 0.9256 - val_accuracy: 0.9219 - val_f1_score: 0.9224 - val_loss: 0.2257 - val_precision: 0.9316 - val_recall: 0.9135
# Epoch 46/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9335 - f1_score: 0.9337 - loss: 0.1845 - precision: 0.9426 - recall: 0.9250
# Epoch 46: val_loss improved from 0.21098 to 0.20583, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 46: val_f1_score improved from 0.92798 to 0.93051, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9335 - f1_score: 0.9337 - loss: 0.1845 - precision: 0.9426 - recall: 0.9250 - val_accuracy: 0.9295 - val_f1_score: 0.9305 - val_loss: 0.2058 - val_precision: 0.9387 - val_recall: 0.9225
# Epoch 47/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9349 - f1_score: 0.9357 - loss: 0.1802 - precision: 0.9442 - recall: 0.9274
# Epoch 47: val_loss improved from 0.20583 to 0.20015, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 47: val_f1_score improved from 0.93051 to 0.93295, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9349 - f1_score: 0.9357 - loss: 0.1802 - precision: 0.9442 - recall: 0.9274 - val_accuracy: 0.9324 - val_f1_score: 0.9330 - val_loss: 0.2001 - val_precision: 0.9406 - val_recall: 0.9255
# Epoch 48/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9346 - f1_score: 0.9354 - loss: 0.1803 - precision: 0.9442 - recall: 0.9268
# Epoch 48: val_loss did not improve from 0.20015
#
# Epoch 48: val_f1_score did not improve from 0.93295
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9346 - f1_score: 0.9354 - loss: 0.1803 - precision: 0.9442 - recall: 0.9268 - val_accuracy: 0.9193 - val_f1_score: 0.9201 - val_loss: 0.2414 - val_precision: 0.9290 - val_recall: 0.9114
# Epoch 49/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9359 - f1_score: 0.9365 - loss: 0.1781 - precision: 0.9449 - recall: 0.9283
# Epoch 49: val_loss did not improve from 0.20015
#
# Epoch 49: val_f1_score did not improve from 0.93295
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9359 - f1_score: 0.9365 - loss: 0.1781 - precision: 0.9449 - recall: 0.9283 - val_accuracy: 0.8828 - val_f1_score: 0.8841 - val_loss: 0.3544 - val_precision: 0.8960 - val_recall: 0.8726
# Epoch 50/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9374 - f1_score: 0.9377 - loss: 0.1755 - precision: 0.9462 - recall: 0.9295
# Epoch 50: val_loss did not improve from 0.20015
#
# Epoch 50: val_f1_score did not improve from 0.93295
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9374 - f1_score: 0.9377 - loss: 0.1755 - precision: 0.9462 - recall: 0.9295 - val_accuracy: 0.9033 - val_f1_score: 0.9041 - val_loss: 0.3163 - val_precision: 0.9133 - val_recall: 0.8952
# Epoch 51/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9375 - f1_score: 0.9380 - loss: 0.1748 - precision: 0.9459 - recall: 0.9302
# Epoch 51: val_loss did not improve from 0.20015
#
# Epoch 51: val_f1_score did not improve from 0.93295
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9375 - f1_score: 0.9380 - loss: 0.1748 - precision: 0.9459 - recall: 0.9302 - val_accuracy: 0.9204 - val_f1_score: 0.9213 - val_loss: 0.2359 - val_precision: 0.9293 - val_recall: 0.9135
# Epoch 52/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9383 - f1_score: 0.9387 - loss: 0.1749 - precision: 0.9467 - recall: 0.9309
# Epoch 52: val_loss did not improve from 0.20015
#
# Epoch 52: val_f1_score did not improve from 0.93295
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9383 - f1_score: 0.9387 - loss: 0.1749 - precision: 0.9467 - recall: 0.9309 - val_accuracy: 0.9257 - val_f1_score: 0.9265 - val_loss: 0.2180 - val_precision: 0.9345 - val_recall: 0.9186
# Epoch 53/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9392 - f1_score: 0.9397 - loss: 0.1695 - precision: 0.9474 - recall: 0.9322
# Epoch 53: val_loss did not improve from 0.20015
#
# Epoch 53: val_f1_score did not improve from 0.93295
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9392 - f1_score: 0.9397 - loss: 0.1695 - precision: 0.9474 - recall: 0.9322 - val_accuracy: 0.9018 - val_f1_score: 0.9027 - val_loss: 0.2917 - val_precision: 0.9140 - val_recall: 0.8918
# Epoch 54/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9380 - f1_score: 0.9386 - loss: 0.1720 - precision: 0.9465 - recall: 0.9309
# Epoch 54: val_loss improved from 0.20015 to 0.18050, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 54: val_f1_score improved from 0.93295 to 0.93782, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9380 - f1_score: 0.9386 - loss: 0.1720 - precision: 0.9465 - recall: 0.9309 - val_accuracy: 0.9377 - val_f1_score: 0.9378 - val_loss: 0.1805 - val_precision: 0.9443 - val_recall: 0.9315
# Epoch 55/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9395 - f1_score: 0.9402 - loss: 0.1672 - precision: 0.9483 - recall: 0.9324
# Epoch 55: val_loss did not improve from 0.18050
#
# Epoch 55: val_f1_score did not improve from 0.93782
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9395 - f1_score: 0.9402 - loss: 0.1672 - precision: 0.9483 - recall: 0.9324 - val_accuracy: 0.9145 - val_f1_score: 0.9152 - val_loss: 0.2535 - val_precision: 0.9243 - val_recall: 0.9063
# Epoch 56/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9409 - f1_score: 0.9410 - loss: 0.1665 - precision: 0.9486 - recall: 0.9337
# Epoch 56: val_loss did not improve from 0.18050
#
# Epoch 56: val_f1_score did not improve from 0.93782
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9409 - f1_score: 0.9410 - loss: 0.1665 - precision: 0.9486 - recall: 0.9337 - val_accuracy: 0.9039 - val_f1_score: 0.9053 - val_loss: 0.2845 - val_precision: 0.9148 - val_recall: 0.8960
# Epoch 57/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9405 - f1_score: 0.9411 - loss: 0.1655 - precision: 0.9486 - recall: 0.9338
# Epoch 57: val_loss did not improve from 0.18050
#
# Epoch 57: val_f1_score did not improve from 0.93782
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9405 - f1_score: 0.9411 - loss: 0.1655 - precision: 0.9486 - recall: 0.9338 - val_accuracy: 0.8874 - val_f1_score: 0.8888 - val_loss: 0.3502 - val_precision: 0.9008 - val_recall: 0.8773
# Epoch 58/500
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9398 - f1_score: 0.9403 - loss: 0.1679 - precision: 0.9477 - recall: 0.9330
# Epoch 58: val_loss did not improve from 0.18050
#
# Epoch 58: val_f1_score improved from 0.93782 to 0.93988, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9398 - f1_score: 0.9403 - loss: 0.1679 - precision: 0.9477 - recall: 0.9330 - val_accuracy: 0.9393 - val_f1_score: 0.9399 - val_loss: 0.1812 - val_precision: 0.9466 - val_recall: 0.9333
# Epoch 59/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9396 - f1_score: 0.9405 - loss: 0.1666 - precision: 0.9479 - recall: 0.9332
# Epoch 59: val_loss did not improve from 0.18050
#
# Epoch 59: val_f1_score did not improve from 0.93988
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9396 - f1_score: 0.9405 - loss: 0.1666 - precision: 0.9479 - recall: 0.9332 - val_accuracy: 0.9211 - val_f1_score: 0.9221 - val_loss: 0.2334 - val_precision: 0.9300 - val_recall: 0.9144
# Epoch 60/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9417 - f1_score: 0.9417 - loss: 0.1632 - precision: 0.9492 - recall: 0.9345
# Epoch 60: val_loss did not improve from 0.18050
#
# Epoch 60: val_f1_score did not improve from 0.93988
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9417 - f1_score: 0.9417 - loss: 0.1632 - precision: 0.9492 - recall: 0.9345 - val_accuracy: 0.9208 - val_f1_score: 0.9212 - val_loss: 0.2357 - val_precision: 0.9298 - val_recall: 0.9129
# Epoch 61/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9389 - f1_score: 0.9394 - loss: 0.1678 - precision: 0.9471 - recall: 0.9319
# Epoch 61: val_loss did not improve from 0.18050
#
# Epoch 61: val_f1_score did not improve from 0.93988
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9389 - f1_score: 0.9394 - loss: 0.1678 - precision: 0.9471 - recall: 0.9319 - val_accuracy: 0.9321 - val_f1_score: 0.9327 - val_loss: 0.1998 - val_precision: 0.9389 - val_recall: 0.9265
# Epoch 62/500
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9420 - f1_score: 0.9422 - loss: 0.1632 - precision: 0.9492 - recall: 0.9353
# Epoch 62: val_loss did not improve from 0.18050
#
# Epoch 62: val_f1_score did not improve from 0.93988
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9420 - f1_score: 0.9422 - loss: 0.1632 - precision: 0.9492 - recall: 0.9353 - val_accuracy: 0.9174 - val_f1_score: 0.9185 - val_loss: 0.2490 - val_precision: 0.9269 - val_recall: 0.9102
# Epoch 63/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9428 - f1_score: 0.9432 - loss: 0.1603 - precision: 0.9503 - recall: 0.9363
# Epoch 63: val_loss did not improve from 0.18050
#
# Epoch 63: val_f1_score did not improve from 0.93988
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9428 - f1_score: 0.9432 - loss: 0.1603 - precision: 0.9503 - recall: 0.9363 - val_accuracy: 0.9138 - val_f1_score: 0.9151 - val_loss: 0.2534 - val_precision: 0.9249 - val_recall: 0.9057
# Epoch 64/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9426 - f1_score: 0.9429 - loss: 0.1613 - precision: 0.9500 - recall: 0.9360
# Epoch 64: val_loss did not improve from 0.18050
#
# Epoch 64: val_f1_score did not improve from 0.93988
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9426 - f1_score: 0.9429 - loss: 0.1613 - precision: 0.9500 - recall: 0.9360 - val_accuracy: 0.9183 - val_f1_score: 0.9189 - val_loss: 0.2436 - val_precision: 0.9264 - val_recall: 0.9115
# Epoch 65/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9420 - f1_score: 0.9421 - loss: 0.1614 - precision: 0.9492 - recall: 0.9352
# Epoch 65: val_loss did not improve from 0.18050
#
# Epoch 65: val_f1_score did not improve from 0.93988
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9420 - f1_score: 0.9421 - loss: 0.1614 - precision: 0.9492 - recall: 0.9352 - val_accuracy: 0.9069 - val_f1_score: 0.9074 - val_loss: 0.2783 - val_precision: 0.9173 - val_recall: 0.8977
# Epoch 66/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9435 - f1_score: 0.9437 - loss: 0.1584 - precision: 0.9506 - recall: 0.9369
# Epoch 66: val_loss did not improve from 0.18050
#
# Epoch 66: val_f1_score did not improve from 0.93988
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9435 - f1_score: 0.9437 - loss: 0.1584 - precision: 0.9506 - recall: 0.9369 - val_accuracy: 0.9301 - val_f1_score: 0.9303 - val_loss: 0.2043 - val_precision: 0.9367 - val_recall: 0.9241
# Epoch 67/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9422 - f1_score: 0.9423 - loss: 0.1622 - precision: 0.9493 - recall: 0.9354
# Epoch 67: val_loss did not improve from 0.18050
#
# Epoch 67: val_f1_score did not improve from 0.93988
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9422 - f1_score: 0.9423 - loss: 0.1622 - precision: 0.9493 - recall: 0.9354 - val_accuracy: 0.9224 - val_f1_score: 0.9228 - val_loss: 0.2296 - val_precision: 0.9304 - val_recall: 0.9155
# Epoch 68/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9426 - f1_score: 0.9429 - loss: 0.1597 - precision: 0.9497 - recall: 0.9362
# Epoch 68: val_loss did not improve from 0.18050
#
# Epoch 68: val_f1_score did not improve from 0.93988
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9426 - f1_score: 0.9429 - loss: 0.1597 - precision: 0.9497 - recall: 0.9362 - val_accuracy: 0.9326 - val_f1_score: 0.9334 - val_loss: 0.1968 - val_precision: 0.9402 - val_recall: 0.9267
# Epoch 69/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9431 - f1_score: 0.9431 - loss: 0.1590 - precision: 0.9499 - recall: 0.9364
# Epoch 69: val_loss did not improve from 0.18050
#
# Epoch 69: val_f1_score did not improve from 0.93988
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9431 - f1_score: 0.9431 - loss: 0.1590 - precision: 0.9499 - recall: 0.9364 - val_accuracy: 0.9206 - val_f1_score: 0.9211 - val_loss: 0.2329 - val_precision: 0.9297 - val_recall: 0.9128
# Epoch 70/500
# 1532/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9431 - f1_score: 0.9435 - loss: 0.1575 - precision: 0.9506 - recall: 0.9366
# Epoch 70: val_loss improved from 0.18050 to 0.17238, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 70: val_f1_score improved from 0.93988 to 0.94184, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9431 - f1_score: 0.9435 - loss: 0.1575 - precision: 0.9506 - recall: 0.9366 - val_accuracy: 0.9411 - val_f1_score: 0.9418 - val_loss: 0.1724 - val_precision: 0.9477 - val_recall: 0.9361
# Epoch 71/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9423 - f1_score: 0.9428 - loss: 0.1601 - precision: 0.9499 - recall: 0.9360
# Epoch 71: val_loss did not improve from 0.17238
#
# Epoch 71: val_f1_score did not improve from 0.94184
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9424 - f1_score: 0.9429 - loss: 0.1601 - precision: 0.9499 - recall: 0.9360 - val_accuracy: 0.9145 - val_f1_score: 0.9163 - val_loss: 0.2531 - val_precision: 0.9255 - val_recall: 0.9074
# Epoch 72/500
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9449 - f1_score: 0.9452 - loss: 0.1522 - precision: 0.9517 - recall: 0.9389
# Epoch 72: val_loss did not improve from 0.17238
#
# Epoch 72: val_f1_score did not improve from 0.94184
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9449 - f1_score: 0.9452 - loss: 0.1522 - precision: 0.9517 - recall: 0.9389 - val_accuracy: 0.9362 - val_f1_score: 0.9372 - val_loss: 0.1843 - val_precision: 0.9432 - val_recall: 0.9313
# Epoch 73/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9425 - f1_score: 0.9431 - loss: 0.1594 - precision: 0.9501 - recall: 0.9362
# Epoch 73: val_loss did not improve from 0.17238
#
# Epoch 73: val_f1_score did not improve from 0.94184
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9425 - f1_score: 0.9431 - loss: 0.1594 - precision: 0.9501 - recall: 0.9362 - val_accuracy: 0.9349 - val_f1_score: 0.9352 - val_loss: 0.1937 - val_precision: 0.9416 - val_recall: 0.9289
# Epoch 74/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9439 - f1_score: 0.9444 - loss: 0.1559 - precision: 0.9514 - recall: 0.9377
# Epoch 74: val_loss did not improve from 0.17238
#
# Epoch 74: val_f1_score did not improve from 0.94184
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9439 - f1_score: 0.9444 - loss: 0.1559 - precision: 0.9514 - recall: 0.9377 - val_accuracy: 0.8663 - val_f1_score: 0.8674 - val_loss: 0.4347 - val_precision: 0.8796 - val_recall: 0.8557
# Epoch 75/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9453 - f1_score: 0.9459 - loss: 0.1520 - precision: 0.9527 - recall: 0.9392
# Epoch 75: val_loss did not improve from 0.17238
#
# Epoch 75: val_f1_score did not improve from 0.94184
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9453 - f1_score: 0.9459 - loss: 0.1520 - precision: 0.9527 - recall: 0.9392 - val_accuracy: 0.8771 - val_f1_score: 0.8792 - val_loss: 0.4050 - val_precision: 0.8907 - val_recall: 0.8680
# Epoch 76/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9462 - f1_score: 0.9466 - loss: 0.1501 - precision: 0.9530 - recall: 0.9403
# Epoch 76: val_loss improved from 0.17238 to 0.17101, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 76: val_f1_score improved from 0.94184 to 0.94345, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9462 - f1_score: 0.9466 - loss: 0.1501 - precision: 0.9530 - recall: 0.9403 - val_accuracy: 0.9429 - val_f1_score: 0.9435 - val_loss: 0.1710 - val_precision: 0.9488 - val_recall: 0.9382
# Epoch 77/500
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9466 - f1_score: 0.9469 - loss: 0.1492 - precision: 0.9532 - recall: 0.9408
# Epoch 77: val_loss did not improve from 0.17101
#
# Epoch 77: val_f1_score did not improve from 0.94345
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9466 - f1_score: 0.9469 - loss: 0.1492 - precision: 0.9532 - recall: 0.9408 - val_accuracy: 0.9416 - val_f1_score: 0.9426 - val_loss: 0.1743 - val_precision: 0.9481 - val_recall: 0.9371
# Epoch 78/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9457 - f1_score: 0.9459 - loss: 0.1491 - precision: 0.9523 - recall: 0.9396
# Epoch 78: val_loss did not improve from 0.17101
#
# Epoch 78: val_f1_score did not improve from 0.94345
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9457 - f1_score: 0.9459 - loss: 0.1491 - precision: 0.9523 - recall: 0.9396 - val_accuracy: 0.9307 - val_f1_score: 0.9315 - val_loss: 0.2034 - val_precision: 0.9381 - val_recall: 0.9251
# Epoch 79/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9452 - f1_score: 0.9456 - loss: 0.1527 - precision: 0.9520 - recall: 0.9393
# Epoch 79: val_loss improved from 0.17101 to 0.16632, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 79: val_f1_score improved from 0.94345 to 0.94475, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9452 - f1_score: 0.9456 - loss: 0.1527 - precision: 0.9520 - recall: 0.9393 - val_accuracy: 0.9438 - val_f1_score: 0.9448 - val_loss: 0.1663 - val_precision: 0.9499 - val_recall: 0.9397
# Epoch 80/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9461 - f1_score: 0.9462 - loss: 0.1505 - precision: 0.9522 - recall: 0.9403
# Epoch 80: val_loss did not improve from 0.16632
#
# Epoch 80: val_f1_score did not improve from 0.94475
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9461 - f1_score: 0.9462 - loss: 0.1505 - precision: 0.9522 - recall: 0.9403 - val_accuracy: 0.9094 - val_f1_score: 0.9105 - val_loss: 0.2742 - val_precision: 0.9188 - val_recall: 0.9023
# Epoch 81/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9459 - f1_score: 0.9464 - loss: 0.1497 - precision: 0.9530 - recall: 0.9399
# Epoch 81: val_loss did not improve from 0.16632
#
# Epoch 81: val_f1_score did not improve from 0.94475
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9459 - f1_score: 0.9464 - loss: 0.1497 - precision: 0.9530 - recall: 0.9399 - val_accuracy: 0.9394 - val_f1_score: 0.9399 - val_loss: 0.1791 - val_precision: 0.9464 - val_recall: 0.9334
# Epoch 82/500
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9482 - f1_score: 0.9484 - loss: 0.1436 - precision: 0.9546 - recall: 0.9424
# Epoch 82: val_loss did not improve from 0.16632
#
# Epoch 82: val_f1_score did not improve from 0.94475
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9482 - f1_score: 0.9484 - loss: 0.1436 - precision: 0.9546 - recall: 0.9424 - val_accuracy: 0.9438 - val_f1_score: 0.9446 - val_loss: 0.1698 - val_precision: 0.9499 - val_recall: 0.9395
# Epoch 83/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9458 - f1_score: 0.9465 - loss: 0.1479 - precision: 0.9528 - recall: 0.9404
# Epoch 83: val_loss did not improve from 0.16632
#
# Epoch 83: val_f1_score did not improve from 0.94475
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9458 - f1_score: 0.9465 - loss: 0.1479 - precision: 0.9528 - recall: 0.9404 - val_accuracy: 0.9166 - val_f1_score: 0.9178 - val_loss: 0.2533 - val_precision: 0.9251 - val_recall: 0.9107
# Epoch 84/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9478 - f1_score: 0.9481 - loss: 0.1450 - precision: 0.9541 - recall: 0.9422
# Epoch 84: val_loss did not improve from 0.16632
#
# Epoch 84: val_f1_score did not improve from 0.94475
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9478 - f1_score: 0.9481 - loss: 0.1450 - precision: 0.9541 - recall: 0.9422 - val_accuracy: 0.9355 - val_f1_score: 0.9361 - val_loss: 0.1914 - val_precision: 0.9420 - val_recall: 0.9304
# Epoch 85/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9457 - f1_score: 0.9463 - loss: 0.1489 - precision: 0.9525 - recall: 0.9403
# Epoch 85: val_loss did not improve from 0.16632
#
# Epoch 85: val_f1_score did not improve from 0.94475
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9457 - f1_score: 0.9463 - loss: 0.1489 - precision: 0.9525 - recall: 0.9403 - val_accuracy: 0.9184 - val_f1_score: 0.9191 - val_loss: 0.2530 - val_precision: 0.9267 - val_recall: 0.9116
# Epoch 86/500
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9482 - f1_score: 0.9483 - loss: 0.1445 - precision: 0.9543 - recall: 0.9424
# Epoch 86: val_loss did not improve from 0.16632
#
# Epoch 86: val_f1_score did not improve from 0.94475
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9482 - f1_score: 0.9483 - loss: 0.1445 - precision: 0.9543 - recall: 0.9424 - val_accuracy: 0.9344 - val_f1_score: 0.9350 - val_loss: 0.1926 - val_precision: 0.9410 - val_recall: 0.9291
# Epoch 87/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9480 - f1_score: 0.9485 - loss: 0.1442 - precision: 0.9544 - recall: 0.9428
# Epoch 87: val_loss did not improve from 0.16632
#
# Epoch 87: val_f1_score did not improve from 0.94475
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9480 - f1_score: 0.9485 - loss: 0.1442 - precision: 0.9544 - recall: 0.9428 - val_accuracy: 0.9414 - val_f1_score: 0.9421 - val_loss: 0.1730 - val_precision: 0.9471 - val_recall: 0.9372
# Epoch 88/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9482 - f1_score: 0.9483 - loss: 0.1433 - precision: 0.9541 - recall: 0.9426
# Epoch 88: val_loss did not improve from 0.16632
#
# Epoch 88: val_f1_score did not improve from 0.94475
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9482 - f1_score: 0.9483 - loss: 0.1433 - precision: 0.9541 - recall: 0.9426 - val_accuracy: 0.9431 - val_f1_score: 0.9435 - val_loss: 0.1733 - val_precision: 0.9484 - val_recall: 0.9387
# Epoch 89/500
# ...
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9544 - f1_score: 0.9549 - loss: 0.1262 - precision: 0.9600 - recall: 0.9500
# Epoch 155: val_loss did not improve from 0.15528
#
# Epoch 155: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9544 - f1_score: 0.9549 - loss: 0.1262 - precision: 0.9600 - recall: 0.9500 - val_accuracy: 0.9445 - val_f1_score: 0.9452 - val_loss: 0.1690 - val_precision: 0.9502 - val_recall: 0.9404
# Epoch 156/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9562 - f1_score: 0.9563 - loss: 0.1231 - precision: 0.9608 - recall: 0.9518
# Epoch 156: val_loss did not improve from 0.15528
#
# Epoch 156: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9562 - f1_score: 0.9563 - loss: 0.1231 - precision: 0.9608 - recall: 0.9518 - val_accuracy: 0.9443 - val_f1_score: 0.9454 - val_loss: 0.1642 - val_precision: 0.9499 - val_recall: 0.9410
# Epoch 157/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9553 - f1_score: 0.9557 - loss: 0.1243 - precision: 0.9605 - recall: 0.9509
# Epoch 157: val_loss did not improve from 0.15528
#
# Epoch 157: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9553 - f1_score: 0.9557 - loss: 0.1243 - precision: 0.9605 - recall: 0.9509 - val_accuracy: 0.9436 - val_f1_score: 0.9443 - val_loss: 0.1690 - val_precision: 0.9494 - val_recall: 0.9393
# Epoch 158/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9554 - f1_score: 0.9557 - loss: 0.1234 - precision: 0.9604 - recall: 0.9511
# Epoch 158: val_loss did not improve from 0.15528
#
# Epoch 158: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9554 - f1_score: 0.9557 - loss: 0.1234 - precision: 0.9604 - recall: 0.9511 - val_accuracy: 0.9438 - val_f1_score: 0.9439 - val_loss: 0.1705 - val_precision: 0.9495 - val_recall: 0.9385
# Epoch 159/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9559 - f1_score: 0.9561 - loss: 0.1221 - precision: 0.9605 - recall: 0.9518
# Epoch 159: val_loss did not improve from 0.15528
#
# Epoch 159: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9559 - f1_score: 0.9561 - loss: 0.1221 - precision: 0.9605 - recall: 0.9518 - val_accuracy: 0.9453 - val_f1_score: 0.9459 - val_loss: 0.1648 - val_precision: 0.9507 - val_recall: 0.9412
# Epoch 160/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9546 - f1_score: 0.9552 - loss: 0.1251 - precision: 0.9598 - recall: 0.9506
# Epoch 160: val_loss did not improve from 0.15528
#
# Epoch 160: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9546 - f1_score: 0.9552 - loss: 0.1251 - precision: 0.9598 - recall: 0.9506 - val_accuracy: 0.9447 - val_f1_score: 0.9454 - val_loss: 0.1680 - val_precision: 0.9498 - val_recall: 0.9410
# Epoch 161/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9561 - f1_score: 0.9562 - loss: 0.1222 - precision: 0.9609 - recall: 0.9515
# Epoch 161: val_loss did not improve from 0.15528
#
# Epoch 161: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9561 - f1_score: 0.9562 - loss: 0.1222 - precision: 0.9609 - recall: 0.9515 - val_accuracy: 0.9468 - val_f1_score: 0.9479 - val_loss: 0.1606 - val_precision: 0.9525 - val_recall: 0.9433
# Epoch 162/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9549 - f1_score: 0.9550 - loss: 0.1267 - precision: 0.9599 - recall: 0.9503
# Epoch 162: val_loss did not improve from 0.15528
#
# Epoch 162: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9549 - f1_score: 0.9551 - loss: 0.1267 - precision: 0.9599 - recall: 0.9503 - val_accuracy: 0.9446 - val_f1_score: 0.9452 - val_loss: 0.1669 - val_precision: 0.9495 - val_recall: 0.9409
# Epoch 163/500
# 1532/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9560 - f1_score: 0.9564 - loss: 0.1221 - precision: 0.9610 - recall: 0.9520
# Epoch 163: val_loss did not improve from 0.15528
#
# Epoch 163: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9560 - f1_score: 0.9564 - loss: 0.1221 - precision: 0.9610 - recall: 0.9520 - val_accuracy: 0.9423 - val_f1_score: 0.9429 - val_loss: 0.1785 - val_precision: 0.9479 - val_recall: 0.9380
# Epoch 164/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9562 - f1_score: 0.9565 - loss: 0.1230 - precision: 0.9612 - recall: 0.9519
# Epoch 164: val_loss did not improve from 0.15528
#
# Epoch 164: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9562 - f1_score: 0.9565 - loss: 0.1230 - precision: 0.9612 - recall: 0.9519 - val_accuracy: 0.9443 - val_f1_score: 0.9448 - val_loss: 0.1679 - val_precision: 0.9493 - val_recall: 0.9403
# Epoch 165/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9557 - f1_score: 0.9561 - loss: 0.1238 - precision: 0.9609 - recall: 0.9514
# Epoch 165: val_loss did not improve from 0.15528
#
# Epoch 165: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9557 - f1_score: 0.9561 - loss: 0.1238 - precision: 0.9609 - recall: 0.9514 - val_accuracy: 0.9297 - val_f1_score: 0.9307 - val_loss: 0.2182 - val_precision: 0.9371 - val_recall: 0.9245
# Epoch 166/500
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9534 - f1_score: 0.9537 - loss: 0.1304 - precision: 0.9588 - recall: 0.9488
# Epoch 166: val_loss did not improve from 0.15528
#
# Epoch 166: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9534 - f1_score: 0.9537 - loss: 0.1304 - precision: 0.9588 - recall: 0.9488 - val_accuracy: 0.9422 - val_f1_score: 0.9432 - val_loss: 0.1786 - val_precision: 0.9485 - val_recall: 0.9380
# Epoch 167/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9558 - f1_score: 0.9560 - loss: 0.1230 - precision: 0.9605 - recall: 0.9516
# Epoch 167: val_loss did not improve from 0.15528
#
# Epoch 167: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9558 - f1_score: 0.9560 - loss: 0.1230 - precision: 0.9605 - recall: 0.9516 - val_accuracy: 0.9197 - val_f1_score: 0.9209 - val_loss: 0.2562 - val_precision: 0.9284 - val_recall: 0.9136
# Epoch 168/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9561 - f1_score: 0.9564 - loss: 0.1236 - precision: 0.9611 - recall: 0.9518
# Epoch 168: val_loss did not improve from 0.15528
#
# Epoch 168: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9561 - f1_score: 0.9564 - loss: 0.1236 - precision: 0.9611 - recall: 0.9518 - val_accuracy: 0.9285 - val_f1_score: 0.9296 - val_loss: 0.2194 - val_precision: 0.9357 - val_recall: 0.9236
# Epoch 169/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9561 - f1_score: 0.9562 - loss: 0.1240 - precision: 0.9607 - recall: 0.9518
# Epoch 169: val_loss did not improve from 0.15528
#
# Epoch 169: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9561 - f1_score: 0.9562 - loss: 0.1240 - precision: 0.9607 - recall: 0.9518 - val_accuracy: 0.9472 - val_f1_score: 0.9477 - val_loss: 0.1592 - val_precision: 0.9515 - val_recall: 0.9439
# Epoch 170/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9573 - f1_score: 0.9576 - loss: 0.1200 - precision: 0.9620 - recall: 0.9533
# Epoch 170: val_loss did not improve from 0.15528
#
# Epoch 170: val_f1_score did not improve from 0.94916
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9573 - f1_score: 0.9576 - loss: 0.1200 - precision: 0.9620 - recall: 0.9533 - val_accuracy: 0.8912 - val_f1_score: 0.8922 - val_loss: 0.3703 - val_precision: 0.9000 - val_recall: 0.8845
# Epoch 171/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9574 - f1_score: 0.9576 - loss: 0.1201 - precision: 0.9620 - recall: 0.9532
# Epoch 171: val_loss improved from 0.15528 to 0.15490, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 171: val_f1_score improved from 0.94916 to 0.94976, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9574 - f1_score: 0.9576 - loss: 0.1201 - precision: 0.9620 - recall: 0.9532 - val_accuracy: 0.9490 - val_f1_score: 0.9498 - val_loss: 0.1549 - val_precision: 0.9538 - val_recall: 0.9458
# Epoch 172/500
# 1533/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9569 - f1_score: 0.9571 - loss: 0.1195 - precision: 0.9616 - recall: 0.9528
# Epoch 172: val_loss did not improve from 0.15490
#
# Epoch 172: val_f1_score did not improve from 0.94976
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9569 - f1_score: 0.9571 - loss: 0.1195 - precision: 0.9616 - recall: 0.9528 - val_accuracy: 0.9445 - val_f1_score: 0.9450 - val_loss: 0.1671 - val_precision: 0.9499 - val_recall: 0.9403
# Epoch 173/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9582 - f1_score: 0.9583 - loss: 0.1162 - precision: 0.9626 - recall: 0.9541
# Epoch 173: val_loss did not improve from 0.15490
#
# Epoch 173: val_f1_score did not improve from 0.94976
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9582 - f1_score: 0.9583 - loss: 0.1162 - precision: 0.9626 - recall: 0.9541 - val_accuracy: 0.9436 - val_f1_score: 0.9442 - val_loss: 0.1735 - val_precision: 0.9488 - val_recall: 0.9398
# Epoch 174/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9593 - f1_score: 0.9596 - loss: 0.1128 - precision: 0.9632 - recall: 0.9561
# Epoch 240: val_loss did not improve from 0.14619
#
# Epoch 240: val_f1_score improved from 0.95279 to 0.95330, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9593 - f1_score: 0.9596 - loss: 0.1128 - precision: 0.9632 - recall: 0.9561 - val_accuracy: 0.9527 - val_f1_score: 0.9533 - val_loss: 0.1471 - val_precision: 0.9569 - val_recall: 0.9498
# Epoch 241/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9618 - f1_score: 0.9619 - loss: 0.1079 - precision: 0.9656 - recall: 0.9583
# Epoch 241: val_loss did not improve from 0.14619
#
# Epoch 241: val_f1_score did not improve from 0.95330
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9618 - f1_score: 0.9619 - loss: 0.1079 - precision: 0.9656 - recall: 0.9583 - val_accuracy: 0.9502 - val_f1_score: 0.9508 - val_loss: 0.1557 - val_precision: 0.9543 - val_recall: 0.9473
# Epoch 242/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9616 - f1_score: 0.9616 - loss: 0.1073 - precision: 0.9653 - recall: 0.9579
# Epoch 242: val_loss improved from 0.14619 to 0.14601, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_loss.weights.h5
#
# Epoch 242: val_f1_score improved from 0.95330 to 0.95361, saving model to /nas/longleaf/home/paulchoi/2stage/tensorboard/checkpointcnn_lstm_acc.weights.h5
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9616 - f1_score: 0.9616 - loss: 0.1073 - precision: 0.9653 - recall: 0.9579 - val_accuracy: 0.9531 - val_f1_score: 0.9536 - val_loss: 0.1460 - val_precision: 0.9571 - val_recall: 0.9501
# Epoch 243/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9622 - f1_score: 0.9622 - loss: 0.1049 - precision: 0.9659 - recall: 0.9586
# Epoch 243: val_loss did not improve from 0.14601
#
# Epoch 243: val_f1_score did not improve from 0.95361
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9622 - f1_score: 0.9622 - loss: 0.1049 - precision: 0.9659 - recall: 0.9586 - val_accuracy: 0.9479 - val_f1_score: 0.9483 - val_loss: 0.1635 - val_precision: 0.9517 - val_recall: 0.9450
# Epoch 244/500
# 1534/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9606 - f1_score: 0.9609 - loss: 0.1101 - precision: 0.9647 - recall: 0.9571
# Epoch 244: val_loss did not improve from 0.14601
#
# Epoch 244: val_f1_score did not improve from 0.95361
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9606 - f1_score: 0.9609 - loss: 0.1101 - precision: 0.9647 - recall: 0.9571 - val_accuracy: 0.9378 - val_f1_score: 0.9382 - val_loss: 0.2042 - val_precision: 0.9430 - val_recall: 0.9335
# Epoch 245/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9615 - f1_score: 0.9618 - loss: 0.1075 - precision: 0.9658 - recall: 0.9578
# Epoch 245: val_loss did not improve from 0.14601
#
# Epoch 245: val_f1_score did not improve from 0.95361
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9615 - f1_score: 0.9618 - loss: 0.1075 - precision: 0.9658 - recall: 0.9578 - val_accuracy: 0.9519 - val_f1_score: 0.9524 - val_loss: 0.1502 - val_precision: 0.9558 - val_recall: 0.9489
# Epoch 246/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9607 - f1_score: 0.9611 - loss: 0.1088 - precision: 0.9649 - recall: 0.9574
# Epoch 246: val_loss did not improve from 0.14601
#
# Epoch 246: val_f1_score did not improve from 0.95361
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9607 - f1_score: 0.9611 - loss: 0.1088 - precision: 0.9649 - recall: 0.9574 - val_accuracy: 0.9510 - val_f1_score: 0.9515 - val_loss: 0.1499 - val_precision: 0.9549 - val_recall: 0.9481
# Epoch 247/500
# 1530/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9614 - f1_score: 0.9613 - loss: 0.1080 - precision: 0.9651 - recall: 0.9576
# Epoch 247: val_loss did not improve from 0.14601
#
# Epoch 247: val_f1_score did not improve from 0.95361
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9614 - f1_score: 0.9613 - loss: 0.1080 - precision: 0.9651 - recall: 0.9577 - val_accuracy: 0.9489 - val_f1_score: 0.9492 - val_loss: 0.1597 - val_precision: 0.9533 - val_recall: 0.9452
# Epoch 248/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9627 - f1_score: 0.9630 - loss: 0.1037 - precision: 0.9667 - recall: 0.9594
# Epoch 248: val_loss did not improve from 0.14601
#
# Epoch 248: val_f1_score did not improve from 0.95361
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9627 - f1_score: 0.9630 - loss: 0.1037 - precision: 0.9667 - recall: 0.9594 - val_accuracy: 0.9499 - val_f1_score: 0.9505 - val_loss: 0.1534 - val_precision: 0.9543 - val_recall: 0.9467
# Epoch 249/500
# 1531/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9596 - f1_score: 0.9599 - loss: 0.1129 - precision: 0.9637 - recall: 0.9561
# Epoch 249: val_loss did not improve from 0.14601
#
# Epoch 249: val_f1_score did not improve from 0.95361
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9597 - f1_score: 0.9599 - loss: 0.1129 - precision: 0.9637 - recall: 0.9561 - val_accuracy: 0.9510 - val_f1_score: 0.9518 - val_loss: 0.1499 - val_precision: 0.9556 - val_recall: 0.9480
# Epoch 250/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9624 - f1_score: 0.9628 - loss: 0.1058 - precision: 0.9661 - recall: 0.9595
# Epoch 274: val_loss did not improve from 0.14410
#
# Epoch 274: val_f1_score did not improve from 0.95425
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9624 - f1_score: 0.9628 - loss: 0.1058 - precision: 0.9661 - recall: 0.9595 - val_accuracy: 0.9341 - val_f1_score: 0.9350 - val_loss: 0.2242 - val_precision: 0.9396 - val_recall: 0.9305
# Epoch 275/500
# 1529/1535 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9629 - f1_score: 0.9629 - loss: 0.1034 - precision: 0.9665 - recall: 0.9595
# Epoch 275: val_loss did not improve from 0.14410
#
# Epoch 275: val_f1_score did not improve from 0.95425
# 1535/1535 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9629 - f1_score: 0.9629 - loss: 0.1034 - precision: 0.9665 - recall: 0.9595 - val_accuracy: 0.9348 - val_f1_score: 0.9358 - val_loss: 0.2046 - val_precision: 0.9409 - val_recall: 0.9308
# Epoch 276/500
#  600/1535 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9624 - f1_score: 0.9625 - loss: 0.1048 - precision: 0.9661 - recall: 0.9590

# %%
# model = pipeline.named_steps['model']
# model.build(input_shape=(None, 50, 2))

# %%
from tensorflow.keras import Input
check_path = os.path.join(checkpoint_dir, MODEL_NAME + 'cnn_lstm_acc.weights.h5')
input_shape = (50, 2)

# _ = pipeline.named_steps['model']( Input(shape=input_shape) )

# 2) Now that all weights exist, load them
pipeline.load_weights(check_path)

# 3) (Optional) verif

# %%
X_test = []
y_test = []

# %%
import csv
def test_traffic_csv_converter(file_path):
    X_train = []
    y_train = []
    with open(file_path, 'r') as csv_file:
        reader = csv.reader(csv_file)
        filename = os.path.splitext(os.path.basename(file_path))[0]
        flow_val = {}
        class_val = {}
        paired_keys = set()
        for i, row in enumerate(reader):
            class_name = row[0]
            src_ip = row[1]
            src_port = row[2]
            dst_ip = row[3]
            dst_port = row[4]
            length = int(row[7])
            ts = np.array(row[8:8+length], dtype=float)
            sizes = np.array(row[9+length:], dtype=int)
            key = (src_ip, src_port, dst_ip, dst_port)
            reverse_key = (dst_ip, dst_port, src_ip, src_port)
            if reverse_key in flow_val:
                # Found the reverse flow
                opposite_ts, opposite_sizes,s_port,d_port = flow_val.pop(reverse_key)
                paired_keys.add(key)
                paired_keys.add(reverse_key)
                if len(opposite_ts) + len(ts) < 40: #flow too small
                    continue
                if "voip" in file_path and class_name =="voip":
                    if reverse_key[0] in client_ip:
                        src_ts, src_sizes = opposite_ts, opposite_sizes
                        src_port,dst_port = s_port,d_port
                        dst_ts, dst_sizes = ts, sizes
                    else:
                        src_ts, src_sizes = ts, sizes
                        dst_ts, dst_sizes = opposite_ts, opposite_sizes
                    x = lstm_vector(src_ts, src_sizes, dst_ts, dst_sizes,src_port,dst_port,True)
                    v = seq_50(src_ts, src_sizes, dst_ts, dst_sizes,src_port,dst_port)
                else:
                    src_ts, src_sizes = opposite_ts, opposite_sizes
                    dst_ts, dst_sizes = ts, sizes
                    x = lstm_vector(src_ts, src_sizes, dst_ts, dst_sizes,src_port,dst_port)
                    v = seq_50(src_ts, src_sizes, dst_ts, dst_sizes,src_port,dst_port)
                if "voip" in file_path and class_name == "voip":
                    voip.append(v)
                    y_train.append(7)
                elif "gaming" in file_path:
                    gaming.append(v)
                    y_train.append(8)
                elif class_name == "web":
                    web.append(v)
                    y_train.append(0)
                elif class_name == "video":
                    video.append(v)
                    y_train.append(1)
                elif class_name == "social":
                    social.append(v)
                    y_train.append(2)
                elif class_name == "email":
                    email.append(v)
                    y_train.append(3)
                elif class_name == "doc":
                    doc.append(v)
                    y_train.append(4)
                elif class_name == "microsoft":
                    microsoft.append(v)
                    y_train.append(5)
                elif class_name == "chat":
                    chat.append(v)
                    y_train.append(6)
                else: #background_flow
                    background.append(v)
                    y_train.append(9)
                X_train.append(x)
            else:
                # Save forward direction flow
                flow_val[key] = (ts, sizes,src_port,dst_port)
                class_val[key] = class_name
    for key, value in flow_val.items():
        if len(value[0]) >= 40:
            if "voip" in file_path:
                ts = value[0][:40]
                sizes = value[1][:40]
                src_port = value[2]
                dst_port = value[3]
                if key[0] in client_ip:
                    sizes = value[1][:40]
                else:
                    sizes = -value[1][:40]
                s_port = np.repeat(src_port,  40) 
                d_port = np.repeat(dst_port,  40) 
                zeros = np.zeros(40)  
                
                v = np.column_stack([ts, sizes,s_port,d_port,zeros])
                X_train.append(v)
                if class_val[key] == "voip": #if the flow is unique
                    y_train.append(7)
                else:
                    y_train.append(9) #if the flow is background
                
                ts = value[0][:50]
                if key[0] in client_ip:
                    sizes = value[1][:50]
                else:
                    sizes = -value[1][:50]
                if len(ts)<50:
                    pad = 50 - len(ts)
                    ts    = np.pad(ts,    (0, pad), mode="constant", constant_values=0)
                    sizes = np.pad(sizes, (0, pad), mode="constant", constant_values=0)
                s_port = np.repeat(src_port,  50)  
                d_port = np.repeat(dst_port,  50)   
                zeros = np.zeros(50)  
                
                v = np.column_stack([ts, sizes,s_port,d_port,zeros])
                if class_val[key] == "voip":
                    voip.append(v)
            elif "gaming" in file_path:
                ts = value[0][:40]
                sizes = value[1][:40]
                src_port =value[2]
                dst_port = value[3]
                s_port = np.repeat(src_port,  40)
                d_port = np.repeat(dst_port,  40)  
                zeros = np.zeros(40)
                
                v = np.column_stack([ts, sizes,s_port,d_port,zeros])
                X_train.append(v)
                y_train.append(8)
                
                ts = value[0][:50]
                sizes = value[1][:50]
                if len(ts)<50:
                    pad = 50 - len(ts)
                    ts    = np.pad(ts,    (0, pad), mode="constant", constant_values=0)
                    sizes = np.pad(sizes, (0, pad), mode="constant", constant_values=0)
                s_port = np.repeat(src_port,  50)  
                d_port = np.repeat(dst_port,  50)  
                zeros = np.zeros(50)
                v = np.column_stack([ts, sizes,s_port,d_port,zeros])
                gaming.append(v)
            
            
    return X_train, y_train

# %%
folder_path = os.path.abspath('..')+"/labeled_test"
docs_path = folder_path + "/docs"
for file_path in iterate_over_files_in_directory(docs_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
web_path = folder_path + "/web"
for file_path in iterate_over_files_in_directory(web_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
chat_path = folder_path + "/chat"
for file_path in iterate_over_files_in_directory(chat_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
social_path = folder_path + "/social"
for file_path in iterate_over_files_in_directory(social_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
video_path = folder_path + "/video"
for file_path in iterate_over_files_in_directory(video_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
voip_path = folder_path + "/voip"
for file_path in iterate_over_files_in_directory(voip_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
gaming_path = folder_path + "/gaming"
for file_path in iterate_over_files_in_directory(gaming_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)
email_path = folder_path + "/email"
for file_path in iterate_over_files_in_directory(email_path):
        X,y = test_traffic_csv_converter(file_path)
        X_test.extend(X)
        y_test.extend(y)

# %%
X_test = np.array(X_test)

# %%
X_test = X_test.astype(np.float32)

# %%
y_test=np.array(y_test)
y_test.shape
# Out:
# (11714,)

# %%
y_pred_prob = pipeline.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
y_test=np.array(y_test)
y_test_categorical = y_test

# %%
def weighted_accuracy(y_true, y_pred, flow_sizes):
    total_flow_size = sum(flow_sizes)
    weighted_acc = 0
    for i, flow_size in enumerate(flow_sizes):
        if y_true[i] == y_pred[i]:
            prediction = 1
        else:
            prediction = 0
        weighted_acc += flow_size * prediction
    weighted_acc /= total_flow_size
    
    return weighted_acc

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
# weighted_accuracy = round(weighted_accuracy(y_test_categorical, y_pred, flow_sizes), 2)
macro_f1 = round(f1_score(y_test_categorical, y_pred, average='macro'), 2)
accuracy = round(accuracy_score(y_test_categorical, y_pred), 2)
average_f1 = round(f1_score(y_test_categorical, y_pred, average='weighted'), 2)
# precision = precision_score(y_test_categorical, y_pred, average=None)
# recall = recall_score(y_test_categorical, y_pred, average=None)
# f1 = f1_score(y_test_categorical, y_pred, average=None)
conf_matrix = confusion_matrix(y_test_categorical, y_pred)

# Print or use the evaluation metrics as needed
# print(f'Weighted Average Accuracy: {weighted_accuracy}')
print(f'Macro Average F1 Score: {macro_f1}')
print(f'Accuracy: {accuracy}')
print(f'Weighted Average F1 Score: {average_f1}')
# print(f'Precision: {precision}')
# print(f'Recall: {recall}')
# print(f'F1 Score: {f1}')
# print(f'Confusion Matrix:\n{conf_matrix}')
# Out:
# Macro Average F1 Score: 0.61
# Accuracy: 0.8
# Weighted Average F1 Score: 0.82

# %%
import seaborn as sns
import matplotlib.pyplot as plt

conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

class_names = ["Web","Video","Social","Email","Doc","Microsoft","Chat","VoIP","Gaming","Background"]
# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names,annot_kws={"size": 14})
# ax = sns.heatmap(conf_matrix_percentage, annot=True, fmt='.2f', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
# for t in ax.texts: t.set_text(t.get_text() + " %")
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('True', fontsize=14)
plt.title('Confusion Matrix')
plt.savefig('40 >40 confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

class_names = ["Web","Video","Social","Email","Doc","Microsoft","Chat","VoIP","Gaming","Background"]

# Plot confusion matrix
plt.figure(figsize=(8, 6))
annot_kws = {"size": 11}
# sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
ax = sns.heatmap(conf_matrix_percentage, annot=True, fmt='.1f', cmap='Blues', xticklabels=class_names, yticklabels=class_names,annot_kws=annot_kws)
for t in ax.texts: t.set_text(t.get_text() + " %")
plt.xlabel('Predicted', fontsize=14)  
plt.ylabel('True', fontsize=14)
plt.title('Confusion Matrix')
plt.savefig('40 >40 confusion_matrixpercent.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# mask for misclassified samples
mask = (y_pred != y_test)

# pick out the probability that the model assigned to its (wrong) prediction
mis_probs = y_pred_prob[mask, y_pred[mask]]

# plot a histogram of those confidences
plt.figure()
plt.hist(mis_probs, bins=20)
plt.xlabel('Softmax probability of predicted class')
plt.ylabel('Number of misclassified samples')
plt.title('Confidence distribution for misclassified samples')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) Select only the misclassified samples
mask = (y_pred != y_test)

# 2) Grab the softmax score assigned to the (wrong) predicted class
mis_probs = y_pred_prob[mask, y_pred[mask]]

# 3) Sort and build the CDF
sorted_probs = np.sort(mis_probs)
cdf = np.arange(1, len(sorted_probs) + 1) / len(sorted_probs)

# 4) Plot
plt.figure()
plt.plot(sorted_probs, cdf)
plt.xlabel('Softmax probability of predicted class')
plt.ylabel('Cumulative proportion')
plt.title('CDF of Softmax Probabilities for Misclassified Samples')
plt.show()

# %%
y_pred = np.argmax(y_pred_prob, axis=1)  # shape (N,)

# — Step 1: Compute the “max confidence” per sample — #
# This finds, for each sample i, the highest softmax‐score across all classes.
confidences = np.max(y_pred_prob, axis=1)  # shape: (N,)

# — Step 2: Build a mask for “keep only if max confidence ≥ 0.9” — #
mask_high_conf = confidences >= 0.9  # shape: (N,), dtype=bool

# — Step 3: Filter your arrays by that mask — #
# If you want to keep only rows with confidence ≥ 0.9 in y_pred_prob:
y_pred_prob_filtered = y_pred_prob[mask_high_conf]  # shape: (__ , C)

# If you also want to keep only those predicted‐class indices:
y_pred_filtered = y_pred[mask_high_conf]

# %%
y_test_filtered = y_test[mask_high_conf]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
# weighted_accuracy = round(weighted_accuracy(y_test_categorical, y_pred, flow_sizes), 2)
macro_f1 = round(f1_score(y_test_filtered, y_pred_filtered, average='macro'), 2)
accuracy = round(accuracy_score(y_test_filtered, y_pred_filtered), 2)
average_f1 = round(f1_score(y_test_filtered, y_pred_filtered, average='weighted'), 2)
# precision = precision_score(y_test_categorical, y_pred, average=None)
# recall = recall_score(y_test_categorical, y_pred, average=None)
# f1 = f1_score(y_test_categorical, y_pred, average=None)
conf_matrix = confusion_matrix(y_test_filtered, y_pred_filtered)

# Print or use the evaluation metrics as needed
# print(f'Weighted Average Accuracy: {weighted_accuracy}')
print(f'Macro Average F1 Score: {macro_f1}')
print(f'Accuracy: {accuracy}')
print(f'Weighted Average F1 Score: {average_f1}')
# print(f'Precision: {precision}')
# print(f'Recall: {recall}')
# print(f'F1 Score: {f1}')
# print(f'Confusion Matrix:\n{conf_matrix}')
# Out:
# Macro Average F1 Score: 0.87
# Accuracy: 0.96
# Weighted Average F1 Score: 0.96

# %%
import seaborn as sns
import matplotlib.pyplot as plt

conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

class_names = ["Web","Video","Social","Email","Doc","Microsoft","Chat","VoIP","Gaming","Background"]
# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names,annot_kws={"size": 14})
# ax = sns.heatmap(conf_matrix_percentage, annot=True, fmt='.2f', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
# for t in ax.texts: t.set_text(t.get_text() + " %")
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('True', fontsize=14)
plt.title('Confusion Matrix')
plt.savefig('40 >40 confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

class_names = ["Web","Video","Social","Email","Doc","Microsoft","Chat","VoIP","Gaming","Background"]

# Plot confusion matrix
plt.figure(figsize=(8, 6))
annot_kws = {"size": 11}
# sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
ax = sns.heatmap(conf_matrix_percentage, annot=True, fmt='.1f', cmap='Blues', xticklabels=class_names, yticklabels=class_names,annot_kws=annot_kws)
for t in ax.texts: t.set_text(t.get_text() + " %")
plt.xlabel('Predicted', fontsize=14)  
plt.ylabel('True', fontsize=14)
plt.title('Confusion Matrix')
plt.savefig('40 >40 confusion_matrixpercent.png', dpi=300, bbox_inches='tight')
plt.show()
